# %%
from IPython.display import display, Math, Latex
import pystan
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![](./assets/DJlogo_alpha.png?raw=true)<!-- .element height="80%" width="80%" -->
#
# <http://www.DataJavelin.com>
# ## Dr Peter Hurley & Dr Phil Rooney

# %% [markdown]
# ## Data Science
#
# $$Data + Model = Prediction$$
# * *Extracting information from Data*<!-- .element: class="fragment" -->
# * *Using information to make predictions, decisions etc*<!-- .element: class="fragment" -->

# %% [markdown]
# <h1> What is Probability? </h1>
# <br >

# %% [markdown]
# <h2> Idea 1: Probability is the Long Run Expected Number of Occurances of an Event </h2>
# <br />
# <br />
#
# <p> When you roll a fair dice once it will come up with only one answer, but after doing this many times each outcome will occur 1/6 of the time. So the probability of an outcome is 1/6. </p>
# <br />
# <p> Another way of saying this: The probability of an event A is equal to the number of ways in which A can occur divided by the number of ways in which any event can happen. </p>
# <br />
# <p> This then helps us answer questions such as, what is the probability of drawing three aces in a row from a shuffled deck of cards? </p>
# <br />
# <p> There are four ways of picking the first ace, out of 52 possible outcomes, three ways of picking the first ace, out of 51 possible outcomes, and two ways of picking the first ace, out of 50 possible outcomes. Therefore:  </p>

# %% [markdown]
# \begin{equation}
# P(3\ Aces) = \frac{4}{52} * \frac{3}{51} * \frac{2}{50}
# \end{equation}

# %% [markdown]
# <p> We can also ask more nuanced questions, such as what is the probability of event A given event B. For example, what is the probability of a card is a King given it is a face card? <p>
# <br >

# %% [markdown]
# \begin{equation}
# P(A\ |\ B) =  \frac{P(A \cap	B)}{P(B)}
# \end{equation}
#
# \begin{equation}
# P(King\ |\ Face\ Card) =  \frac{4}{12} =  \frac{1}{3}
# \end{equation}

# %% [markdown]
# <p> Suppose a family has two children and suppose one of the children is a boy. What is the probability that both children are boys? <p>

# %% [markdown]
# <p> Total number of ways in which a family can have two children: </p>
#
# <br >
#
# <p> {BB}, {BG}, {GB}, {GG} </p>
#
# <br >
#
# <p> Of these three involve at least one boy, and of these only one pairing is two boys so: </p>
#
# <br >
#
#
# \begin{equation}
# P(Two\ Boys\ |\ One\ child\ definitely\ a\ boy) =  \frac{1}{3}
# \end{equation}
#
# <br >
#
# <p> A nice extension to this problem is: Suppose a family has two children and suppose one of the children is a boy born on a Tuesday. What is the probability that both children are boys? <p>

# %% [markdown]
# <p> The Monte Hall Problem:Suppose you're on a game show, and you're given the choice of three doors: Behind one door is a car; behind the others, goats. You pick a door, say No. 1, and the host, who knows what's behind the doors, opens another door, say No. 3, which has a goat. He then says to you, "Do you want to pick door No. 2?" Is it to your advantage to switch your choice? <p>
# <br >

# %% [markdown]
# \begin{equation}
# P(Prize\ behind\ any\ random\ door) =  \frac{1}{3}
# \end{equation}
#
# <br >
#
# \begin{equation}
# P(Keep\ Door\ 1\ and\ Win) =  \frac{P(Prize\ Door\ 1\ and\ Host\ Opens\ Door\ 3)}{Host\ Opens\ Door\ 3}
# \end{equation}
#
# <br >
#
# \begin{equation}
# P(Prize\ Door\ 1\ and\ Host\ Opens\ Door\ 3) =  \frac{1}{3} * \frac{1}{2}  =  \frac{1}{6}
# \end{equation}
#
# <br >
#
# <p> The probability the host opens door 3 depends on which door the prize is behind. </p>
#
# \begin{equation}
# P(Host\ Door\ 3) =  P(Host\ Door\ 3\ |\ Prize\ Door\ 1) * P(Prize\ Door\ 1) + P(Host\ Door\ 3\ |\ Prize\ Door\ 2) * P(Prize\ Door\ 3)+ P(Host\ Door\ 3\ |\ Prize\ Door\ 2) * P(Prize\ Door\ 3)
# \end{equation}
#
# <br >
#
# \begin{equation}
# P(Host\ Door\ 3) = \frac{1}{2} * \frac{1}{3} + 1 * \frac{1}{3} + 0*\frac{1}{3} = \frac{1}{2}
# \end{equation}
#
# <br >
#
# <p> So the probability of winning if we keep our door is: </p>
#
# <br >
#
# \begin{equation}
# P(Keep\ Door\ 1\ and\ Win) = \frac{\frac{1}{6}}{\frac{1}{2}} = \frac{1}{3}
# \end{equation}
#
# <br >
#
# <p> And so the probability of winning if we swap is: <\p>
#
# \begin{equation}
# P(Swap\ Door\ 2\ and\ Win) = 1 - \frac{1}{3} =  \frac{2}{3}
# \end{equation}

# %% [markdown]
# <p> We can manipulate these equations as in other areas of maths as we did above <p>
# <br >

# %% [markdown]
# \begin{equation}
# P(A\ |\ B) =  \frac{P(A \cap	B)}{P(B)}
# \end{equation}
#
# \begin{equation}
# P(A \cap	B) = P(A) * P(B | A)
# \end{equation}
#
# \begin{equation}
# P(A \cap	B) = P(B) * P(A | B)
# \end{equation}
#
# \begin{equation}
# P(A) * P(B | A) = P(B) * P(A | B)
# \end{equation}
#
# \begin{equation}
# P(B | A) = \frac{P(B) * P(A | B)}{P(A)}
# \end{equation}

# %% [markdown]
# <p> This last equation is Bayes Theorem, a source of heated debate among statisticians throughout the 20th century. </p>
#
# <br >
#
# <p> You may wonder what the fuss is as surely everyone accepts the above? </p>
#
# <br >
#
# <p> The issue comes in when we consider how far we can apply this equation. </p>

# %% [markdown]
# ## Probabilistic models
# * A model describes data that one could observe from a system
# * Uses probability theory to express all forms of uncertainty and noise associated with our model
# * Inverse probability (i.e. Bayes rule) to infer parameters, adapt models, make predictions and learn from data.
#
#
# <br >
#
# A good example of how Bayesian probability is more intuitive is to think of a situation such as the probability of rain, given the sky is cloudy, or that there is a sprinkler nearby. We use prior information to decide if it has rained, rather than just looking at the number of times it has rained in past.
#
# <br >
#
# Alternatively there can also be cases where a frequentist model breaks down. Suppose you are an astronomer looking at Saturn with an old telescope. Combining many measurements of the shape of the planet will not improve your result on resolving the shape. However given a model of how a planet with a ring or without you can test how well each model describes Saturn and infer the correct shape.
#
# <br>
#
# Other key cases are those in which you can never repeat the experiment, e.g. modelling how the universe grew since the big bang or the diversification of songbirds in the Andes.

# %% [markdown]
# \begin{equation}
# P(B | A) = \frac{P(B) * P(A | B)}{P(A)}
# \end{equation}
#
# <p> P(B | A) = Posterior <br >
#     P(B) = Prior <br >
#     P(A | B) = Likelihood <br >
#     P(A) = Marginal Likelihood <br >
# </p>
#
# <br>
#
# <p> Transparent way of including model prior information <br >
# Gives full probability distribution
# </p>
# <br >
#
# <p> As the area under a posterior must equal one the marginal likelihood can be thought of as a normalistion value, and so the equation is often written as: </p>
#
# <br >
#
# \begin{equation}
# P(B | A) \propto P(B) * P(A | B)
# \end{equation}
#
# <br >
#
# <p> In that case your posterior is your prior state of belief being updated by the new data. </p>
#
# <br >
#
# <p> More precisely however you P(A) is actually an integral which is often difficult to solve, and must be done numerically,  motivates the need for MCMC type sampling. MCMC-like algorithms will generate points proportionally to the posterior values in each region. A simplistic way of thinking about this is a sampler generates some initial starting parameter values, calculates how well a model with these parameters explains the data and then generates a new set of parameter values nearby. If these new values are an improvement we always accept the new point and move there, otherwise we have a small chance we move there. The exact way in which this works varies by method. <p>
#
# <br >
#
# <p> So far so good, but there is a lot of debate and discomfort with how you choose an appropriate prior. However disagreements over what prior is used can at least be transparent, and the correct description of the current state of knowledge before new data is an important and necessary part of debate. </p>

# %% [markdown]
# ### Why bother with all this Bayesian probabilistic stuff?
# * Prior information help us extract more information from data

# %% [markdown]
# ### Prob. model of straight line
# $\mathbf{y}=m\mathbf{x}+c + \epsilon$
#
# likelihood = $p(\mathbf{y}|m,c,\mathbf{x}) = \mathcal{N}(m\mathbf{x}+c,\sigma^2)$
#
# prior = $p(m,c) = \mathcal{N}(0,\Sigma_p)$
#
# posterior (after a bit of maths)
#
# $p(m,c|\mathbf{y},\mathbf{x}) \propto  \mathcal{N}(\sigma^{-2}(\sigma^{-2}\mathbf{x}\mathbf{x}^T + \Sigma_{p}^{-1})^{-1}\mathbf{x}\mathbf{y},$
# $\sigma^{-2}\mathbf{x}\mathbf{x}^T + \Sigma_{p}^{-1})$
#
# Simple example straight line, error only in y, simple gaussian prior
#
# What happens if intercept is positive? gets complicated fast

# %% [markdown]
# ![](./assets/line_1.png?raw=true)

# %% [markdown]
# ![](./assets/line_2.png?raw=true)

# %% [markdown]
# Have prior information on intercept
#
# $c \sim \mathcal{N}(0.3,0.1)$

# %% [markdown]
# ![](./assets/line_3.png?raw=true)

# %% [markdown]
# ![](./assets/line_4.png?raw=true)

# %% [markdown]
# * The uncertainty in our inferred model parameters contains information.
#
# * We do not want to just know the best answer, we
# want to know how uncertain we are.

# %% [markdown]
# <img src="./assets/max_like.png" alt="Drawing" style="width: 600px;"/>
#
# <img src="./assets/max_like_2.png" alt="Drawing" style="width: 600px;"/>
#
# <img src="./assets/curved_posterior.png" alt="Drawing" style="width: 600px;"/>
#
# <img src="./assets/curved_posterior_probx.png" alt="Drawing" style="width: 600px;"/>
#
# <img src="./assets/curved_posterior_proby.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# ### Using Uncertianty in decision making means making better decisions
#
# * Business consider risk when making decisions
# * Uncertianty should be considered when making decisions based on predictions
#
# See [Blog post on Bayesian Decision making](https://pdh21.github.io/jekyll/update/2019/06/06/FACYNation_BDT.html)

# %% [markdown]
# # Stan
# <img src="http://mc-stan.org/images/stan_logo.png" alt="Drawing" style="width: 100px;"/>
#
# * Language for building probabilistic models
# * Algorithms for fitting probabilistic models
# * Interfaces for using probabilistic models

# %% [markdown]
# ## Language
# Specify probabilisitic model: the joint probability distribution function,
#
# $$p(\theta,x)$$
#
# * $\theta$ = parameters
# * $x$ = data
# * $p$ = model
#
#
# Stan is a language:
# * Statically typed, imperative
# * User can define programs using parameters, data and  $\log p(\theta,x)$
# * Any program can be written as long as $\log p(\theta,x)$ is differentiable
#
#
# Statically typed like C, C++. i.e. types declared at compile time rather than run time like Python.
#
# Imperative, you tell the compiler what you want to happen, step by step

# %% [markdown]
# ## Algorithms
# * Bayesian Inference: No U-Turn Hamiltonian Monte Carlo,
#     - $p(\theta|x)$ approximated with $[\theta^1,\theta^2,..\theta^N]$
# * Approximate Bayesian Inference: Variational Inference,
#     - $\hat{p}(\theta|x) \approx q(\hat{\phi})$, where $\phi = argmin_{\phi} D_{KL}(q(\theta|\phi)||p(\theta,x))$
# * Optimisation: Max
#     - $\hat{\theta} = argmax_{\theta} p(\theta,x)$

# %% [markdown]
# ## Interfaces
# * CmdStan,PyStan,RStan
# * C++ API
# * C++ auto-diff library
# * Software built with Stan: RStanArm, brms, prophet

# %% [markdown]
# <p> As an example lets consider a question of if a coin is fair or not. We begin with a flat prior and update it as we flip a coin. <p>

# %%
coin_model ="""// Inferring a Rate
data { 
  int<lower=1> n; 
  int<lower=0> h;
} 
parameters {
  real<lower=0,upper=1> theta;
} 
model {
  // Prior Distribution for Rate Theta
  theta ~ beta(1, 1);
  
  // Observed Counts
  h ~ binomial(n, theta);
}"""

sm=pystan.StanModel(model_code=coin_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_b8b89c3550faa3c1ec5a2fff83579316 NOW.
# /home/philip/anaconda3/envs/machine_learning/lib/python3.6/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpp_s6fcp7/stanfit4anon_model_b8b89c3550faa3c1ec5a2fff83579316_2753564075764435161.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
model_data={
        'n':1,
        'h':1,
}

# %%
fit=sm.sampling(data=model_data,chains=4,iter=1000,seed=12329)

# %%
print(fit)

plt.plot(np.arange(0, fit['theta'].size), fit['theta'])
plt.xlabel('Sample')
plt.ylabel('Theta')
plt.show()

plt.hist(fit['theta'])
plt.xlabel('Theta')
plt.ylabel('Number of Samples')
plt.show
# Out:
# Inference for Stan model: anon_model_b8b89c3550faa3c1ec5a2fff83579316.
# 4 chains, each with iter=1000; warmup=500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=2000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# theta   0.37  4.1e-4   0.01   0.35   0.37   0.37   0.38   0.39    688   1.01
# lp__   -1323    0.02   0.71  -1325  -1323  -1323  -1323  -1323    977    1.0
#
# Samples were drawn using NUTS at Mon Feb 24 18:05:28 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
model_data={
        'n':10,
        'h':7,
}

fit=sm.sampling(data=model_data,chains=4,iter=1000,seed=12329)

print(fit)

plt.hist(fit['theta'])
plt.xlabel('Theta')
plt.ylabel('Number of Samples')
plt.show
# Out:
# Inference for Stan model: anon_model_b8b89c3550faa3c1ec5a2fff83579316.
# 4 chains, each with iter=1000; warmup=500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=2000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# theta   0.67  4.5e-3   0.13   0.39   0.58   0.67   0.76   0.89    820    1.0
# lp__   -8.15    0.03   0.73 -10.06  -8.31  -7.88  -7.69  -7.64    528   1.01
#
# Samples were drawn using NUTS at Mon Feb 24 17:13:07 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
model_data={
        'n':100,
        'h':54,
}

fit=sm.sampling(data=model_data,chains=4,iter=1000,seed=12329)

print(fit)

plt.hist(fit['theta'])
plt.xlabel('Theta')
plt.ylabel('Number of Samples')
plt.show
# Out:
# Inference for Stan model: anon_model_b8b89c3550faa3c1ec5a2fff83579316.
# 4 chains, each with iter=1000; warmup=500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=2000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# theta   0.54  2.0e-3   0.05   0.44   0.51   0.54   0.57   0.64    612   1.01
# lp__  -70.89    0.02   0.69  -72.9 -71.07 -70.61 -70.44 -70.39    823   1.01
#
# Samples were drawn using NUTS at Mon Feb 24 17:13:58 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# <p> Sometimes our data may come in a more complex form. For instance imagine if you have a game that involves coin tosses. You filp a coin until you flip a heads and a tails in a row. Your opponent flips a coin until they flip two heads in a row. All the information you have is who won each game. From this you want to understand if one coin was biased or not. </p>
#
# <p> As HT and HH in two coin flips are equally likely we may run the code above and see how close our theta value is to 0.5 <p>
#
# <p> After 2,000 flips your opponent has won 747 times but you have won 1,253. </p>

# %%
model_data={
        'n':2000,
        'h':747,
}

fit=sm.sampling(data=model_data,chains=4,iter=1000,seed=12329)

print(fit)

plt.hist(fit['theta'])
plt.xlabel('Theta')
plt.ylabel('Number of Samples')
plt.show
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-123-16fd31363d4c> in <module>
#       4 }
#       5
# ----> 6 fit=sm.sampling(data=model_data,chains=4,iter=1000,seed=12329)
#       7
#       8 print(fit)
#
# ~/anaconda3/envs/machine_learning/lib/python3.6/site-packages/pystan/model.py in sampling(self, data, pars, chains, iter, warmup, thin, seed, init, sample_file, diagnostic_file, verbose, algorithm, control, n_jobs, **kwargs)
#     719
#     720         seed = pystan.misc._check_seed(seed)
# --> 721         fit = self.fit_class(data, seed)
#     722
#     723         m_pars = fit._get_param_names()
#
# stanfit4anon_model_78f7cfc1daf3a7ccdfbee88500ff4157_4633776124771051138.pyx in stanfit4anon_model_78f7cfc1daf3a7ccdfbee88500ff4157_4633776124771051138.StanFit4Model.__cinit__()
#
# RuntimeError: Exception: variable does not exist; processing stage=data initialization; variable name=nmax; base type=int  (in 'unknown file name' at line 2)

# %% [markdown]
# <p> So can we conclusively say that our coin was biased? <p>
#
# <p> Once again this is a case where we should have questioned our underlying assumptions, i.e. that both opponents had a 50% chance of winning. In future this will be covered in part by prior predictive checks which should give us intuition on how our model behaves. For now let us first generate data in the way described assuming both players have a fair coin </p>

# %%
bob_wins = 0
alice_wins = 0

for i in range(5000):
    bob_seq = np.array([])
    alice_seq = np.array([])
    bob_poss_win = 0
    alice_poss_win = 0
    while bob_wins + alice_wins < 2000:
        bob_seq = np.append(bob_seq, np.random.randint(2,size=1))
        alice_seq = np.append(alice_seq, np.random.randint(2,size=1))
        if np.prod((bob_seq.size > 1) and (bob_seq[-2:] == [0,0])):
            bob_poss_win = 1
        if np.prod((alice_seq.size > 1) and (alice_seq[-2:] == [0,1])):
            alice_poss_win = 1
        if (bob_poss_win == 1) and (alice_poss_win == 1):
            bob_seq = np.array([])
            alice_seq = np.array([])
            bob_poss_win = 0
            alice_poss_win = 0
        elif bob_poss_win == 1:
            bob_wins += 1 
            bob_seq = np.array([])
            alice_seq = np.array([])
            bob_poss_win = 0
        elif alice_poss_win == 1:
            alice_wins += 1 
            bob_seq = np.array([])
            alice_seq = np.array([])
            alice_poss_win = 0
            
print(bob_wins)
print(alice_wins)
# Out:
# 730
# 1270

# %% [markdown]
# <p> Understanding a problem deeply is important when building a model. Misunderstanding a model can lead to misinterpretation. In this case there is a subtle difference, if you need to flip HT and first flip a H you will not win if on the next coin toss you flip another H - but you are still only one flip away. If you need to flip HH and after one H toss flip a T, you are again two flips away from winning. </p>
#
# <br >
#
# ## Probabilistic Programming
# *Define probability models & solve automatically*
#
# <img src="./assets/probprog.png" alt="Drawing" style="width: 600px;"/>

# %%
rate_diff = """// Difference Between Two Rates
data { 
  int<lower=1> n1; 
  int<lower=1> n2; 
  int<lower=0> k1;
  int<lower=0> k2;
} 
parameters {
  real<lower=0,upper=1> theta1;
  real<lower=0,upper=1> theta2;
} 
transformed parameters {
  real<lower=-1,upper=1> delta;
  delta <- theta1 - theta2;
}
model {
  // Prior Distribution for Rate Theta
  theta1 ~ beta(1, 1);
  theta2 ~ beta(1, 1);
  // Observed Counts
  k1 ~ binomial(n1, theta1);
  k2 ~ binomial(n2, theta2);
}"""

sm=pystan.StanModel(model_code=rate_diff)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_b712d3d58d6ce64ce339b400e820a652 NOW.
# /home/philip/anaconda3/envs/machine_learning/lib/python3.6/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpwqstlihk/stanfit4anon_model_b712d3d58d6ce64ce339b400e820a652_8312184069863553979.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
model_data = {
    'k1': 50,
    'k2': 62,
    'n1': 100,
    'n2': 100,
}

fit=sm.sampling(data=model_data,chains=4,iter=1000,seed=12329)

plot.hist(delta)
plt.show()

# %% [markdown]
# <p> So let us now consider a model where there are more than one unknown and interacting parameters. In this case of five sets of eager volunteers distributed an equal number of surveys to randomly selected houses. Unfortunately nobody recorded the number of surveys in each bundle and now we need to estimate the rate of return. Assuming there was no more than 500 surveys in a bundle we can attempt to calculate this. But first let us discuss how we think the posterior will look. </p>
# <br >

# %%
plt.plot(np.arange(0, 20), ....)
# Out:
# /home/philip/anaconda3/envs/machine_learning/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# <p> # Inferring Return Rate and Numbers of Surveys from Observed Returns
# <br >
# # Observed Returns
# <br >
#
# for (i in 1:m){
# <br >
#
# k[i] ~ dbin(theta,n)
# <br >
#
# }
# <br >
#
# \# Priors on Rate Theta and Number n
# <br >
#
# theta ~ dbeta(1,1)
# <br >
# n ~ dcat(p[])
# <br >
# for (i in 1:nmax){
# <br >
# p[i] <- 1/nmax
# <br >
# }<p>
# <br >

# %%
survey_model = """data { 
  int<lower=0> nmax;
  int<lower=0> m;
  int<lower=0,upper=nmax> k[m];
}
transformed data {
  int<lower=0> nmin;  // Minimal possible n
  
  nmin <- max(k);
}
parameters {
  real<lower=0,upper=1> theta;
}
transformed parameters {
  vector[nmax] lp_parts;  // Log probability for each n

  // First part of the trick for mixture model
  for (n in 1:nmax)
    if (n < nmin)
      lp_parts[n] <- log(1.0 / nmax) + negative_infinity();  // Zero probability
    else
      lp_parts[n] <- log(1.0 / nmax) + binomial_log(k, n, theta); 
}
model {
  // Second part of the trick for mixture model
  increment_log_prob(log_sum_exp(lp_parts));
}
generated quantities {
  int<lower=1,upper=nmax> n;
  simplex[nmax] prob_n;
  
  // Transforming lp_parts to probabilities of each n
  prob_n <- softmax(lp_parts);
  n <- categorical_rng(prob_n);
}"""

sm=pystan.StanModel(model_code=survey_model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_78f7cfc1daf3a7ccdfbee88500ff4157 NOW.
# /home/philip/anaconda3/envs/machine_learning/lib/python3.6/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpxoktcphc/stanfit4anon_model_78f7cfc1daf3a7ccdfbee88500ff4157_4633776124771051138.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %% [markdown]
# !!! DISCLAIMER !!!
# <br >
# Stan is not the correct tool to use if you are working with discrete parameters - in this case n. Expect errors and do this using a more suitable tool for real world applications.
#
# <br >

# %%
model_data={
    'k': np.array([16, 18, 22, 25, 27]),
    'm': 5,
    'nmax': 500
}

fit=sm.sampling(data=model_data,chains=4,iter=1000,seed=12329)

print(fit)
# Out:
# WARNING:pystan:n_eff / iter for parameter lp_parts[1] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[2] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[3] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[4] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[5] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[6] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[7] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[8] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[9] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[10] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[11] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[12] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[13] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[14] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[15] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[16] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[17] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[18] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[19] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[20] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[21] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[22] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[23] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[24] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[25] is nan!
# WARNING:pystan:n_eff / iter for parameter lp_parts[26] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[1] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[2] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[3] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[4] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[5] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[6] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[7] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[8] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[9] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[10] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[11] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[12] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[13] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[14] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[15] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[16] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[17] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[18] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[19] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[20] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[21] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[22] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[23] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[24] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[25] is nan!
# WARNING:pystan:n_eff / iter for parameter prob_n[26] is nan!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter lp_parts[1] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[2] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[3] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[4] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[5] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[6] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[7] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[8] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[9] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[10] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[11] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[12] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[13] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[14] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[15] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[16] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[17] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[18] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[19] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[20] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[21] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[22] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[23] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[24] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[25] is nan!
# WARNING:pystan:Rhat for parameter lp_parts[26] is nan!
# WARNING:pystan:Rhat for parameter prob_n[1] is nan!
# WARNING:pystan:Rhat for parameter prob_n[2] is nan!
# WARNING:pystan:Rhat for parameter prob_n[3] is nan!
# WARNING:pystan:Rhat for parameter prob_n[4] is nan!
# WARNING:pystan:Rhat for parameter prob_n[5] is nan!
# WARNING:pystan:Rhat for parameter prob_n[6] is nan!
# WARNING:pystan:Rhat for parameter prob_n[7] is nan!
# WARNING:pystan:Rhat for parameter prob_n[8] is nan!
# WARNING:pystan:Rhat for parameter prob_n[9] is nan!
# WARNING:pystan:Rhat for parameter prob_n[10] is nan!
# WARNING:pystan:Rhat for parameter prob_n[11] is nan!
# WARNING:pystan:Rhat for parameter prob_n[12] is nan!
# WARNING:pystan:Rhat for parameter prob_n[13] is nan!
# WARNING:pystan:Rhat for parameter prob_n[14] is nan!
# WARNING:pystan:Rhat for parameter prob_n[15] is nan!
# WARNING:pystan:Rhat for parameter prob_n[16] is nan!
# WARNING:pystan:Rhat for parameter prob_n[17] is nan!
# WARNING:pystan:Rhat for parameter prob_n[18] is nan!
# WARNING:pystan:Rhat for parameter prob_n[19] is nan!
# WARNING:pystan:Rhat for parameter prob_n[20] is nan!
# WARNING:pystan:Rhat for parameter prob_n[21] is nan!
# WARNING:pystan:Rhat for parameter prob_n[22] is nan!
# WARNING:pystan:Rhat for parameter prob_n[23] is nan!
# WARNING:pystan:Rhat for parameter prob_n[24] is nan!
# WARNING:pystan:Rhat for parameter prob_n[25] is nan!
# WARNING:pystan:Rhat for parameter prob_n[26] is nan!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:19 of 2000 iterations ended with a divergence (0.95%).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Inference for Stan model: anon_model_78f7cfc1daf3a7ccdfbee88500ff4157.
# 4 chains, each with iter=1000; warmup=500; thin=1;
# post-warmup draws per chain=500, total post-warmup draws=2000.
#
#                 mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# theta           0.18  6.7e-3   0.14   0.04   0.07   0.13   0.25   0.56    441   1.01
# lp_parts[1]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[2]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[3]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[4]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[5]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[6]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[7]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[8]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[9]     -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[10]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[11]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[12]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[13]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[14]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[15]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[16]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[17]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[18]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[19]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[20]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[21]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[22]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[23]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[24]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[25]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[26]    -inf     nan    nan   -inf   -inf   -inf   -inf   -inf    nan    nan
# lp_parts[27]  -177.4    4.75  76.42 -303.5 -244.9 -178.9 -114.4 -42.13    258   1.02
# lp_parts[28]  -169.6    4.72  75.52 -294.8 -236.3 -170.6 -106.8 -37.25    256   1.02
# lp_parts[29]  -162.8    4.68  74.63 -287.1 -228.8 -163.5 -100.4 -33.51    254   1.02
# lp_parts[30]  -156.8    4.65  73.74 -280.2 -222.1 -157.1 -94.81 -30.51    252   1.02
# lp_parts[31]  -151.4    4.61  72.86 -273.9 -216.0 -151.3 -89.73 -28.09    250   1.02
# lp_parts[32]  -146.4    4.57  71.98 -268.1 -210.3 -146.0 -85.12 -26.14    248   1.02
# lp_parts[33]  -141.9    4.54   71.1 -262.6 -205.0 -141.0 -80.89 -24.57    245   1.02
# lp_parts[34]  -137.6     4.5  70.23 -257.5 -200.0 -136.4  -77.0 -23.34    243   1.02
# lp_parts[35]  -133.7    4.47  69.36 -252.6 -195.3 -132.0 -73.39  -22.7    241   1.02
# lp_parts[36]  -130.0    4.43   68.5 -248.0 -190.9 -128.0 -70.04 -22.16    239   1.02
# lp_parts[37]  -126.5    4.39  67.64 -243.7 -186.7 -124.1 -66.91 -21.85    237   1.02
# lp_parts[38]  -123.2    4.36  66.78 -239.5 -182.7 -120.5 -63.99  -21.6    235   1.02
# lp_parts[39]  -120.1    4.32  65.93 -235.6 -178.9 -117.0 -61.26 -21.32    233   1.02
# lp_parts[40]  -117.2    4.28  65.09 -231.8 -175.2 -113.7 -58.69 -21.31    231   1.02
# lp_parts[41]  -114.5    4.25  64.25 -228.1 -171.7 -110.5 -56.28 -21.27    229   1.02
# lp_parts[42]  -111.9    4.21  63.42 -224.6 -168.4 -107.5 -54.01 -21.24    227   1.02
# lp_parts[43]  -109.4    4.18  62.59 -221.2 -165.2 -104.7 -51.87 -21.15    225   1.02
# lp_parts[44]  -107.0    4.14  61.77 -218.0 -162.1 -101.9 -49.91 -21.19    223   1.02
# lp_parts[45]  -104.8     4.1  60.95 -214.8 -159.1 -99.34  -48.0  -21.2    221   1.02
# lp_parts[46]  -102.6    4.07  60.14 -211.8 -156.2 -96.81 -46.21  -21.0    219   1.02
# lp_parts[47]  -100.6    4.03  59.34 -208.9 -153.4 -94.38 -44.76 -20.93    216   1.02
# lp_parts[48]  -98.66     4.0  58.54 -206.0 -150.8 -92.04 -43.21 -20.87    214   1.02
# lp_parts[49]   -96.8    3.96  57.76 -203.3 -148.2 -89.79 -41.87 -20.77    212   1.02
# lp_parts[50]  -95.01    3.93  56.98 -200.6 -145.7 -87.63 -40.82 -20.77    211   1.02
# lp_parts[51]  -93.31    3.89   56.2 -198.0 -143.2 -85.54 -39.99  -20.7    209   1.02
# lp_parts[52]  -91.68    3.85  55.44 -195.5 -140.9 -83.52 -38.95 -20.74    207   1.02
# lp_parts[53]  -90.11    3.81  54.68 -193.0 -138.6  -81.8 -38.16 -20.76    206   1.02
# lp_parts[54]  -88.62    3.78  53.94 -190.6 -136.3 -79.92 -37.42 -20.73    204   1.02
# lp_parts[55]  -87.19    3.74   53.2 -188.3 -134.2  -78.1 -36.75  -20.7    203   1.02
# lp_parts[56]  -85.81     3.7  52.47 -186.1 -132.1 -76.58 -36.19 -20.66    201   1.02
# lp_parts[57]  -84.49    3.66  51.75 -183.8 -130.0 -75.55 -35.46 -20.62    200   1.02
# lp_parts[58]  -83.23    3.62  51.04 -181.7 -128.0  -74.0 -34.79 -20.58    199   1.02
# lp_parts[59]  -82.02    3.59  50.35 -179.6 -126.1 -72.44  -34.6 -20.57    197   1.02
# lp_parts[60]  -80.86    3.55  49.66 -177.5 -124.2 -70.93 -34.53 -20.54    196   1.02
# lp_parts[61]  -79.75    3.51  48.99 -175.5 -122.3 -69.56 -33.91 -20.52    195   1.02
# lp_parts[62]  -78.68    3.47  48.33 -173.6 -120.5 -68.58 -33.47 -20.53    194   1.02
# lp_parts[63]  -77.65    3.44  47.68 -171.7 -118.8 -67.33 -33.01 -20.53    193   1.02
# lp_parts[64]  -76.67     3.4  47.05 -169.8 -117.1 -66.26 -32.71 -20.53    191   1.02
# lp_parts[65]  -75.72    3.36  46.43 -168.0 -115.4 -65.59 -32.07 -20.57    190   1.02
# lp_parts[66]  -74.82    3.33  45.82 -166.2 -113.8 -64.33 -31.99 -20.58    189   1.02
# lp_parts[67]  -73.95    3.29  45.23 -164.4 -112.4 -63.42 -31.51 -20.55    189   1.02
# lp_parts[68]  -73.12    3.26  44.66 -162.7 -110.9 -62.78 -31.27 -20.53    188   1.02
# lp_parts[69]  -72.32    3.22   44.1 -161.0 -109.5 -62.26 -31.09 -20.54    187   1.02
# lp_parts[70]  -71.56    3.19  43.56 -159.3 -108.1 -61.38  -30.9 -20.52    187   1.02
# lp_parts[71]  -70.83    3.15  43.04 -157.7 -106.6 -60.34 -30.64 -20.49    186   1.02
# lp_parts[72]  -70.12    3.12  42.53 -156.1 -105.7 -59.66 -30.35 -20.49    186   1.02
# lp_parts[73]  -69.45    3.08  42.05 -154.6 -104.5 -59.38 -30.11  -20.5    186   1.02
# lp_parts[74]  -68.81    3.05  41.58 -153.0 -103.8 -58.86 -29.99  -20.5    186   1.02
# lp_parts[75]   -68.2    3.02  41.14 -151.5 -102.9 -58.37 -29.71  -20.5    186   1.02
# lp_parts[76]  -67.61    2.98  40.71 -150.1 -101.9 -57.44 -29.27 -20.53    186   1.02
# lp_parts[77]  -67.05    2.95  40.31 -148.6 -100.7 -56.78 -29.15 -20.53    187   1.02
# lp_parts[78]  -66.51    2.91  39.93 -147.2 -100.0 -56.21 -28.86 -20.51    188   1.02
# lp_parts[79]   -66.0    2.87  39.57 -145.8 -98.89 -55.67 -28.86 -20.49    190   1.02
# lp_parts[80]  -65.51    2.84  39.23 -144.4 -98.34  -55.4 -28.92 -20.49    191   1.02
# lp_parts[81]  -65.05     2.8  38.93 -143.0  -97.7  -55.0 -28.93 -20.47    194   1.02
# lp_parts[82]  -64.61    2.76  38.64 -141.7 -97.18 -54.38 -28.69 -20.48    196   1.02
# lp_parts[83]  -64.19    2.72  38.38 -140.4 -96.79 -53.91 -28.57 -20.49    199   1.02
# lp_parts[84]  -63.79    2.69  38.15 -139.1 -96.08 -53.45  -28.7 -20.48    202   1.02
# lp_parts[85]  -63.41    2.65  37.94 -137.8 -95.43 -53.54 -28.67 -20.49    206   1.02
# lp_parts[86]  -63.05     2.6  37.76 -136.6 -94.49 -53.47 -28.74 -20.48    210   1.02
# lp_parts[87]  -62.72    2.56   37.6 -135.4 -93.99 -53.12 -28.66 -20.47    215   1.02
# lp_parts[88]   -62.4    2.52  37.48 -134.2 -93.04 -52.82  -28.4 -20.47    221   1.02
# lp_parts[89]   -62.1    2.48  37.38 -133.0 -92.43 -52.41 -28.47 -20.46    227   1.02
# lp_parts[90]  -61.82    2.44  37.31 -131.8 -91.95  -52.0 -28.49 -20.46    234   1.01
# lp_parts[91]  -61.55     2.4  37.27 -130.6 -91.51 -51.79  -28.4 -20.46    241   1.01
# lp_parts[92]   -61.3    2.36  37.25 -130.0 -90.55 -51.44 -28.21 -20.45    249   1.01
# lp_parts[93]  -61.07    2.32  37.27 -130.6 -89.74 -51.36 -27.96 -20.47    258   1.01
# lp_parts[94]  -60.86    2.28  37.31 -131.7 -89.05 -50.81  -28.0 -20.48    268   1.01
# lp_parts[95]  -60.66    2.24  37.38 -130.7 -88.25 -50.57 -27.98 -20.49    278   1.01
# lp_parts[96]  -60.47     2.2  37.48 -132.3 -87.36 -50.31 -27.93 -20.49    290   1.01
# lp_parts[97]  -60.31    2.16  37.61 -135.1 -86.59 -49.94 -27.86  -20.5    302   1.01
# lp_parts[98]  -60.15    2.14  37.76 -138.0 -85.73 -49.75 -27.76 -20.51    312   1.01
# lp_parts[99]  -60.01    2.11  37.94 -140.8 -84.89 -49.52 -27.74 -20.49    323   1.01
# lp_parts[100] -59.89    2.08  38.15 -143.7 -84.29 -49.07 -27.66 -20.47    335   1.01
# lp_parts[101] -59.78    2.06  38.38 -146.6 -83.87 -49.16 -27.58 -20.46    347   1.01
# lp_parts[102] -59.68    2.04  38.64 -149.5 -83.13 -48.96 -27.64 -20.47    361   1.01
# lp_parts[103]  -59.6    2.01  38.93 -152.4 -82.91 -48.77  -27.6 -20.47    375   1.01
# lp_parts[104] -59.53    1.99  39.24 -155.4 -82.62 -48.71 -27.47 -20.46    390   1.01
# lp_parts[105] -59.47    1.97  39.57 -158.3 -82.66 -48.54 -27.42 -20.45    405   1.01
# lp_parts[106] -59.42    1.94  39.93 -161.3 -82.18 -48.38 -27.46 -20.45    422   1.01
# lp_parts[107] -59.39    1.92  40.31 -164.2 -81.65 -48.44 -27.42 -20.46    439   1.01
# lp_parts[108] -59.36    1.91  40.72 -167.2 -80.93 -48.92 -27.44 -20.46    456   1.01
# lp_parts[109] -59.35    1.89  41.14 -170.2 -80.59 -48.75 -27.39 -20.45    472   1.01
# lp_parts[110] -59.35    1.88  41.59 -173.2 -80.09 -48.65 -27.28 -20.44    487   1.01
# lp_parts[111] -59.36    1.87  42.05 -176.2 -79.48 -48.24 -27.14 -20.45    503    1.0
# lp_parts[112] -59.39    1.87  42.54 -179.2 -79.21 -47.94  -27.0 -20.46    519    1.0
# lp_parts[113] -59.42    1.86  43.05 -182.3 -78.86 -48.26 -26.92 -20.45    533    1.0
# lp_parts[114] -59.46    1.87  43.57 -185.3 -78.13 -48.32 -27.01 -20.46    540    1.0
# lp_parts[115] -59.52    1.89  44.11 -188.4 -77.91 -48.13 -26.96 -20.46    547    1.0
# lp_parts[116] -59.58     1.9  44.67 -191.4 -77.69 -48.19 -27.19 -20.46    554    1.0
# lp_parts[117] -59.65    1.91  45.24 -194.5 -77.32 -48.24 -27.14 -20.47    561    1.0
# lp_parts[118] -59.74    1.93  45.83 -197.6 -76.82  -47.8 -27.06 -20.47    567    1.0
# lp_parts[119] -59.83    1.94  46.44 -200.7 -76.57 -47.57 -27.05 -20.47    573    1.0
# lp_parts[120] -59.93    1.96  47.06 -203.8 -76.37 -47.45 -27.04 -20.46    578    1.0
# lp_parts[121] -60.04    1.97  47.69 -206.9  -75.8 -47.29 -26.88 -20.48    584    1.0
# lp_parts[122] -60.17    1.99  48.34 -210.0 -75.86 -47.13 -26.93 -20.47    589    1.0
# lp_parts[123] -60.29    2.01   49.0 -213.2 -76.01 -47.34 -26.96 -20.47    593    1.0
# lp_parts[124] -60.43    2.03  49.67 -216.3 -75.73 -47.07 -26.86 -20.48    597    1.0
# lp_parts[125] -60.58    2.06  50.36 -219.5 -75.24 -46.93 -26.87  -20.5    600    1.0
# lp_parts[126] -60.73    2.08  51.06 -222.6 -74.95 -46.86 -26.83 -20.47    603    1.0
# lp_parts[127]  -60.9     2.1  51.76 -225.8 -74.73 -46.65 -26.88 -20.49    606    1.0
# lp_parts[128] -61.07    2.13  52.48 -229.0 -74.68 -46.39 -26.65 -20.48    608    1.0
# lp_parts[129] -61.25    2.15  53.21 -232.1 -74.44 -46.06 -26.66 -20.47    610    1.0
# lp_parts[130] -61.43    2.18  53.95 -235.3 -74.26  -45.8 -26.56 -20.46    612    1.0
# lp_parts[131] -61.63    2.21  54.69 -238.5 -74.35 -45.69 -26.53 -20.47    614    1.0
# lp_parts[132] -61.83    2.24  55.45 -241.7 -74.33 -45.41 -26.56 -20.48    615    1.0
# lp_parts[133] -62.04    2.27  56.21 -245.0 -74.09 -45.21 -26.61 -20.45    616    1.0
# lp_parts[134] -62.26     2.3  56.99 -248.2 -74.39 -44.88 -26.66 -20.45    616    1.0
# lp_parts[135] -62.48    2.33  57.77 -251.4 -74.33 -44.75 -26.52 -20.45    617    1.0
# lp_parts[136] -62.71    2.36  58.56 -254.6 -74.09 -44.68 -26.55 -20.46    617    1.0
# lp_parts[137] -62.95    2.39  59.35 -257.9  -73.8  -45.1 -26.67 -20.46    617    1.0
# lp_parts[138] -63.19    2.42  60.15 -261.1 -73.63 -44.91 -26.72 -20.46    618    1.0
# lp_parts[139] -63.44    2.45  60.96 -264.4 -73.79  -44.7 -26.78 -20.46    618    1.0
# lp_parts[140]  -63.7    2.49  61.78 -267.6 -74.06 -44.77 -26.75 -20.45    618    1.0
# lp_parts[141] -63.97    2.52   62.6 -270.9 -73.49 -45.01 -26.89 -20.47    618    1.0
# lp_parts[142] -64.24    2.55  63.43 -274.2 -73.62 -45.15 -26.74 -20.46    618    1.0
# lp_parts[143] -64.51    2.59  64.26 -277.5 -73.28 -45.21 -26.65 -20.46    618    1.0
# lp_parts[144]  -64.8    2.62   65.1 -280.7 -72.86 -45.18 -26.69 -20.47    617    1.0
# lp_parts[145] -65.09    2.65  65.95 -284.0 -72.51 -45.15 -26.72 -20.48    617    1.0
# lp_parts[146] -65.38    2.69   66.8 -287.3 -72.36 -44.92 -26.78 -20.49    617    1.0
# lp_parts[147] -65.68    2.73  67.65 -290.6 -72.04 -45.08 -26.65  -20.5    616    1.0
# lp_parts[148] -65.99    2.76  68.51 -293.9 -72.05 -45.04 -26.68  -20.5    616    1.0
# lp_parts[149] -66.31     2.8  69.37 -297.3 -72.01 -44.91 -26.75 -20.49    615    1.0
# lp_parts[150] -66.62    2.83  70.24 -300.6 -72.01 -44.88  -26.8 -20.47    615    1.0
# lp_parts[151] -66.95    2.87  71.11 -303.9 -72.13  -44.9 -26.75 -20.46    614    1.0
# lp_parts[152] -67.28    2.91  71.99 -307.2 -71.98 -44.95 -26.79 -20.46    614    1.0
# lp_parts[153] -67.61    2.94  72.87 -310.6 -71.74 -44.88 -26.66 -20.44    613    1.0
# lp_parts[154] -67.95    2.98  73.76 -313.9 -71.88 -44.88 -26.72 -20.44    612    1.0
# lp_parts[155]  -68.3    3.02  74.64 -317.3 -71.74 -44.95 -26.67 -20.44    612    1.0
# lp_parts[156] -68.65    3.06  75.53 -320.6  -72.0 -44.85 -26.58 -20.44    611    1.0
# lp_parts[157] -69.01    3.09  76.43 -324.0 -71.97 -44.99 -26.61 -20.45    610    1.0
# lp_parts[158] -69.37    3.13  77.33 -327.4 -72.16 -45.04  -26.5 -20.45    610    1.0
# lp_parts[159] -69.74    3.17  78.23 -330.7 -72.19 -45.11 -26.57 -20.47    609    1.0
# lp_parts[160] -70.11    3.21  79.13 -334.1 -72.58 -45.19 -26.59 -20.47    608    1.0
# lp_parts[161] -70.48    3.25  80.04 -337.5 -72.65 -45.14 -26.62 -20.48    608    1.0
# lp_parts[162] -70.87    3.29  80.95 -340.9 -73.16 -44.95 -26.61 -20.48    607    1.0
# lp_parts[163] -71.25    3.33  81.86 -344.3 -73.42 -44.83 -26.46 -20.49    606    1.0
# lp_parts[164] -71.64    3.36  82.78 -347.6 -73.81 -44.91 -26.65 -20.48    605    1.0
# lp_parts[165] -72.04     3.4   83.7 -351.0 -74.21 -44.83 -26.81 -20.47    605    1.0
# lp_parts[166] -72.44    3.44  84.62 -354.4 -73.89 -44.51 -26.76 -20.47    604    1.0
# lp_parts[167] -72.84    3.48  85.54 -357.9 -74.35 -44.34 -26.68 -20.46    603    1.0
# lp_parts[168] -73.25    3.52  86.46 -361.3 -73.87 -44.24 -26.57 -20.45    602    1.0
# lp_parts[169] -73.66    3.56  87.39 -364.7 -73.39 -44.01 -26.47 -20.45    601    1.0
# lp_parts[170] -74.08     3.6  88.32 -368.1 -72.92 -43.82 -26.47 -20.45    601    1.0
# lp_parts[171]  -74.5    3.64  89.25 -371.5 -72.45 -43.55 -26.71 -20.46    600    1.0
# lp_parts[172] -74.93    3.68  90.19 -375.0 -71.99 -43.42 -26.81 -20.46    599    1.0
# lp_parts[173] -75.36    3.73  91.12 -378.4 -71.53 -43.11 -26.69 -20.45    598    1.0
# lp_parts[174] -75.79    3.77  92.06 -381.8 -71.07 -43.16 -26.58 -20.45    598    1.0
# lp_parts[175] -76.23    3.81   93.0 -385.3 -70.62 -43.19 -26.54 -20.46    597    1.0
# lp_parts[176] -76.67    3.85  93.94 -388.7 -70.17 -43.11 -26.53 -20.46    596    1.0
# lp_parts[177] -77.12    3.89  94.89 -392.2 -69.73 -43.19 -26.61 -20.46    595    1.0
# lp_parts[178] -77.57    3.93  95.83 -395.6 -69.35 -43.29 -26.66 -20.46    595    1.0
# lp_parts[179] -78.03    3.97  96.78 -399.1 -69.47 -43.23 -26.71 -20.46    594    1.0
# lp_parts[180] -78.48    4.01  97.73 -402.5  -70.3 -43.09 -26.71 -20.48    593    1.0
# lp_parts[181] -78.95    4.05  98.68 -406.0 -71.03 -42.86 -26.64 -20.48    593    1.0
# lp_parts[182] -79.41     4.1  99.63 -409.5 -71.17  -42.8 -26.62 -20.48    592    1.0
# lp_parts[183] -79.88    4.14 100.58 -412.9  -71.0 -42.71 -26.51 -20.48    591    1.0
# lp_parts[184] -80.35    4.18 101.53 -416.4 -71.63 -42.64 -26.57  -20.5    590    1.0
# lp_parts[185] -80.83    4.22 102.49 -419.9 -72.45 -42.63 -26.65  -20.5    590    1.0
# lp_parts[186] -81.31    4.26 103.45 -423.4 -73.28 -42.54 -26.55 -20.51    589    1.0
# lp_parts[187] -81.79     4.3 104.41 -426.9 -74.11 -42.28 -26.59  -20.5    588    1.0
# lp_parts[188] -82.28    4.35 105.36 -430.4 -74.94 -42.35 -26.61  -20.5    588    1.0
# lp_parts[189] -82.77    4.39 106.33 -433.8 -75.78 -42.47 -26.52  -20.5    587    1.0
# lp_parts[190] -83.27    4.43 107.29 -437.3 -76.62 -42.48 -26.47 -20.51    586    1.0
# lp_parts[191] -83.76    4.47 108.25 -440.8 -77.46  -42.3 -26.41 -20.51    586    1.0
# lp_parts[192] -84.26    4.52 109.22 -444.3 -78.31 -42.51 -26.33  -20.5    585    1.0
# lp_parts[193] -84.77    4.56 110.18 -447.9 -79.16 -42.35 -26.25 -20.49    584    1.0
# lp_parts[194] -85.27     4.6 111.15 -451.4 -80.01 -42.34 -26.13 -20.48    584    1.0
# lp_parts[195] -85.78    4.64 112.12 -454.9 -80.87 -42.36 -26.15 -20.49    583    1.0
# lp_parts[196]  -86.3    4.69 113.08 -458.4 -81.73 -42.54  -26.1 -20.49    582    1.0
# lp_parts[197] -86.82    4.73 114.05 -461.9 -82.59 -42.44 -26.06 -20.48    582    1.0
# lp_parts[198] -87.34    4.77 115.02 -465.4 -83.46 -42.25 -25.91 -20.47    581    1.0
# lp_parts[199] -87.86    4.81  116.0 -469.0 -84.33 -42.05 -25.84 -20.47    581    1.0
# lp_parts[200] -88.38    4.86 116.97 -472.5  -85.2 -41.86 -25.86 -20.47    580    1.0
# lp_parts[201] -88.91     4.9 117.94 -476.0 -86.08 -41.95 -25.86 -20.48    579    1.0
# lp_parts[202] -89.45    4.94 118.92 -479.6 -86.96 -41.86 -25.84 -20.48    579    1.0
# lp_parts[203] -89.98    4.99 119.89 -483.1 -87.84  -41.9 -25.85 -20.47    578    1.0
# lp_parts[204] -90.52    5.03 120.87 -486.6 -88.72 -41.93 -25.92 -20.47    578    1.0
# lp_parts[205] -91.06    5.07 121.85 -490.2 -89.61 -41.82 -25.87 -20.47    577    1.0
# lp_parts[206]  -91.6    5.11 122.82 -493.7  -90.5 -41.54 -25.94 -20.47    577    1.0
# lp_parts[207] -92.15    5.16  123.8 -497.3 -91.39 -41.74 -25.98 -20.48    576    1.0
# lp_parts[208]  -92.7     5.2 124.78 -500.8 -92.29 -41.63 -26.13 -20.47    576    1.0
# lp_parts[209] -93.25    5.24 125.76 -504.4 -93.19 -41.69 -26.23 -20.46    575    1.0
# lp_parts[210] -93.81    5.29 126.74 -507.9 -94.09 -41.66  -26.3 -20.48    574    1.0
# lp_parts[211] -94.36    5.33 127.72 -511.5 -94.99  -41.5 -26.44 -20.47    574    1.0
# lp_parts[212] -94.92    5.37 128.71 -515.1  -95.9  -41.3 -26.45 -20.47    573    1.0
# lp_parts[213] -95.49    5.42 129.69 -518.6 -96.81 -41.35 -26.44 -20.47    573    1.0
# lp_parts[214] -96.05    5.46 130.67 -522.2 -97.72 -41.55 -26.34 -20.47    572    1.0
# lp_parts[215] -96.62    5.51 131.66 -525.8 -98.63 -41.63 -26.32 -20.47    572    1.0
# lp_parts[216] -97.19    5.55 132.64 -529.3 -99.55 -41.69 -26.38 -20.47    571    1.0
# lp_parts[217] -97.77    5.59 133.63 -532.9 -100.4 -41.66 -26.41 -20.46    571    1.0
# lp_parts[218] -98.34    5.64 134.61 -536.5 -101.3 -41.43 -26.27 -20.47    570   1.01
# lp_parts[219] -98.92    5.68  135.6 -540.1 -102.3 -41.43 -26.15 -20.47    570   1.01
# lp_parts[220]  -99.5    5.72 136.59 -543.7 -103.2 -41.65 -26.09 -20.47    569   1.01
# lp_parts[221] -100.0    5.77 137.58 -547.3 -104.1 -41.65 -26.16 -20.47    569   1.01
# lp_parts[222] -100.6    5.81 138.56 -550.8 -105.1 -41.73 -26.14 -20.49    569   1.01
# lp_parts[223] -101.2    5.86 139.55 -554.4 -106.0  -41.5 -26.23 -20.49    568   1.01
# lp_parts[224] -101.8     5.9 140.54 -558.0 -106.9 -41.61 -26.32 -20.49    568   1.01
# lp_parts[225] -102.4    5.94 141.53 -561.6 -107.9 -41.64 -26.24 -20.49    567   1.01
# lp_parts[226] -103.0    5.99 142.52 -565.2 -108.8 -41.54 -26.22  -20.5    567   1.01
# lp_parts[227] -103.6    6.03 143.52 -568.8 -109.8 -41.58 -26.28 -20.49    566   1.01
# lp_parts[228] -104.2    6.07 144.51 -572.4 -110.7 -41.54 -26.34 -20.49    566   1.01
# lp_parts[229] -104.8    6.12  145.5 -576.0 -111.7 -41.34 -26.41 -20.48    565   1.01
# lp_parts[230] -105.4    6.16 146.49 -579.6 -112.6 -41.12 -26.42 -20.48    565   1.01
# lp_parts[231] -106.0    6.21 147.48 -583.3 -113.6 -41.27 -26.41  -20.5    565   1.01
# lp_parts[232] -106.6    6.25 148.48 -586.9 -114.5  -41.2 -26.47 -20.51    564   1.01
# lp_parts[233] -107.2     6.3 149.47 -590.5 -115.5 -41.34 -26.48 -20.51    564   1.01
# lp_parts[234] -107.8    6.34 150.47 -594.1 -116.4 -41.29 -26.45 -20.51    563   1.01
# lp_parts[235] -108.5    6.38 151.46 -597.7 -117.4 -41.42 -26.52 -20.51    563   1.01
# lp_parts[236] -109.1    6.43 152.46 -601.3 -118.4 -41.56 -26.55 -20.51    563   1.01
# lp_parts[237] -109.7    6.47 153.45 -605.0 -119.3 -41.37 -26.51 -20.51    562   1.01
# lp_parts[238] -110.3    6.52 154.45 -608.6 -120.3 -41.41 -26.44  -20.5    562   1.01
# lp_parts[239] -110.9    6.56 155.44 -612.2 -121.3 -41.45 -26.41  -20.5    561   1.01
# lp_parts[240] -111.6     6.6 156.44 -615.8 -122.2 -41.44 -26.37  -20.5    561   1.01
# lp_parts[241] -112.2    6.65 157.44 -619.5 -123.2 -41.46 -26.46 -20.51    561   1.01
# lp_parts[242] -112.8    6.69 158.44 -623.1 -124.2 -41.55 -26.41  -20.5    560   1.01
# lp_parts[243] -113.5    6.74 159.43 -626.7 -125.2 -41.63 -26.41  -20.5    560   1.01
# lp_parts[244] -114.1    6.78 160.43 -630.4 -126.1 -41.76 -26.39  -20.5    560   1.01
# lp_parts[245] -114.7    6.83 161.43 -634.0 -127.1 -41.89  -26.3  -20.5    559   1.01
# lp_parts[246] -115.4    6.87 162.43 -637.7 -128.1 -41.91 -26.21  -20.5    559   1.01
# lp_parts[247] -116.0    6.92 163.43 -641.3 -129.1 -41.82 -26.15  -20.5    559   1.01
# lp_parts[248] -116.7    6.96 164.43 -644.9 -130.1 -42.02 -26.04 -20.48    558   1.01
# lp_parts[249] -117.3     7.0 165.43 -648.6 -131.1 -42.26 -25.91 -20.48    558   1.01
# lp_parts[250] -117.9    7.05 166.43 -652.2 -132.1 -42.11 -25.92 -20.47    558   1.01
# lp_parts[251] -118.6    7.09 167.43 -655.9 -133.1 -42.41 -25.88 -20.48    557   1.01
# lp_parts[252] -119.2    7.14 168.43 -659.5 -134.1 -42.62 -25.89 -20.48    557   1.01
# lp_parts[253] -119.9    7.18 169.43 -663.2 -135.1 -42.83 -25.78 -20.48    556   1.01
# lp_parts[254] -120.5    7.23 170.43 -666.9 -136.1 -42.93 -25.72 -20.48    556   1.01
# lp_parts[255] -121.2    7.27 171.44 -670.5 -137.1 -43.16 -25.71 -20.48    556   1.01
# lp_parts[256] -121.9    7.32 172.44 -674.2 -138.1 -43.42 -25.68 -20.48    555   1.01
# lp_parts[257] -122.5    7.36 173.44 -677.8 -139.1 -43.59 -25.69 -20.47    555   1.01
# lp_parts[258] -123.2    7.41 174.44 -681.5 -140.1 -43.75 -25.64 -20.47    554   1.01
# lp_parts[259] -123.8    7.45 175.45 -685.2 -141.1 -43.53  -25.7 -20.47    554   1.01
# lp_parts[260] -124.5     7.5 176.45 -688.8 -142.1  -43.3 -25.81 -20.46    554   1.01
# lp_parts[261] -125.2    7.54 177.45 -692.5 -143.1 -43.08 -25.74 -20.46    553   1.01
# lp_parts[262] -125.8    7.59 178.46 -696.2 -144.1 -42.86 -25.63 -20.46    553   1.01
# lp_parts[263] -126.5    7.63 179.46 -699.8 -145.1 -42.64  -25.6 -20.46    553   1.01
# lp_parts[264] -127.2    7.68 180.47 -703.5 -146.2 -42.42 -25.54 -20.45    552   1.01
# lp_parts[265] -127.9    7.72 181.47 -707.2 -147.2  -42.2 -25.58 -20.45    552   1.01
# lp_parts[266] -128.5    7.77 182.48 -710.9 -148.2 -41.98 -25.57 -20.45    552   1.01
# lp_parts[267] -129.2    7.81 183.48 -714.6 -149.2 -41.77 -25.49 -20.44    551   1.01
# lp_parts[268] -129.9    7.86 184.49 -718.2 -150.2 -41.56 -25.42 -20.44    551   1.01
# lp_parts[269] -130.6     7.9 185.49 -721.9 -151.3 -41.35 -25.49 -20.44    551   1.01
# lp_parts[270] -131.2    7.95  186.5 -725.6 -152.3  -41.2 -25.42 -20.45    550   1.01
# lp_parts[271] -131.9     8.0  187.5 -729.3 -153.3 -41.22 -25.41 -20.45    550   1.01
# lp_parts[272] -132.6    8.04 188.51 -733.0 -154.4 -41.08 -25.34 -20.45    550   1.01
# lp_parts[273] -133.3    8.09 189.52 -736.7 -155.4 -41.36 -25.34 -20.46    549   1.01
# lp_parts[274] -134.0    8.13 190.52 -740.4 -156.4 -41.68 -25.33 -20.47    549   1.01
# lp_parts[275] -134.7    8.18 191.53 -744.0 -157.5 -41.99 -25.35 -20.47    549   1.01
# lp_parts[276] -135.4    8.22 192.54 -747.7 -158.5 -42.16  -25.3 -20.47    548   1.01
# lp_parts[277] -136.1    8.27 193.54 -751.4 -159.5 -42.37 -25.34 -20.47    548   1.01
# lp_parts[278] -136.8    8.31 194.55 -755.1 -160.6 -42.21 -25.27 -20.47    548   1.01
# lp_parts[279] -137.4    8.36 195.56 -758.8 -161.6  -42.4 -25.29 -20.48    547   1.01
# lp_parts[280] -138.1     8.4 196.57 -762.5 -162.7 -42.56 -25.29 -20.49    547   1.01
# lp_parts[281] -138.8    8.45 197.57 -766.2 -163.7 -42.67 -25.31  -20.5    547   1.01
# lp_parts[282] -139.5    8.49 198.58 -769.9 -164.8 -42.98 -25.29  -20.5    547   1.01
# lp_parts[283] -140.2    8.54 199.59 -773.6 -165.8  -43.3 -25.34 -20.51    546   1.01
# lp_parts[284] -140.9    8.58  200.6 -777.3 -166.9 -43.62 -25.38 -20.52    546   1.01
# lp_parts[285] -141.7    8.63 201.61 -781.1 -167.9 -43.94 -25.37 -20.52    546   1.01
# lp_parts[286] -142.4    8.68 202.62 -784.8 -169.0 -44.26 -25.36 -20.53    545   1.01
# lp_parts[287] -143.1    8.72 203.63 -788.5 -170.0 -44.58  -25.4 -20.52    545   1.01
# lp_parts[288] -143.8    8.77 204.64 -792.2 -171.1 -44.91 -25.37 -20.51    545   1.01
# lp_parts[289] -144.5    8.81 205.65 -795.9 -172.1 -45.23  -25.3 -20.52    545   1.01
# lp_parts[290] -145.2    8.86 206.66 -799.6 -173.2 -45.56 -25.25 -20.53    544   1.01
# lp_parts[291] -145.9     8.9 207.67 -803.3 -174.2 -45.89 -25.19 -20.51    544   1.01
# lp_parts[292] -146.6    8.95 208.68 -807.0 -175.3 -46.21 -25.22 -20.51    544   1.01
# lp_parts[293] -147.3    8.99 209.69 -810.8 -176.4 -46.55 -25.24 -20.52    544   1.01
# lp_parts[294] -148.1    9.04  210.7 -814.5 -177.4 -46.88 -25.19 -20.52    543   1.01
# lp_parts[295] -148.8    9.09 211.71 -818.2 -178.5 -47.21  -25.2 -20.52    543   1.01
# lp_parts[296] -149.5    9.13 212.72 -821.9 -179.6 -47.55  -25.2 -20.52    543   1.01
# lp_parts[297] -150.2    9.18 213.73 -825.6 -180.6 -47.88 -25.19 -20.51    542   1.01
# lp_parts[298] -150.9    9.22 214.74 -829.4 -181.7 -48.22 -25.17 -20.51    542   1.01
# lp_parts[299] -151.7    9.27 215.75 -833.1 -182.8 -48.56 -25.12 -20.51    542   1.01
# lp_parts[300] -152.4    9.32 216.76 -836.8 -183.8  -48.9 -25.04 -20.51    541   1.01
# lp_parts[301] -153.1    9.36 217.77 -840.6 -184.9 -49.24 -24.99 -20.51    541   1.01
# lp_parts[302] -153.8    9.41 218.78 -844.3 -186.0 -49.58 -25.02 -20.51    541   1.01
# lp_parts[303] -154.6    9.45  219.8 -848.0 -187.0 -49.93 -24.96  -20.5    541   1.01
# lp_parts[304] -155.3     9.5 220.81 -851.8 -188.1 -50.27 -24.96 -20.49    540   1.01
# lp_parts[305] -156.0    9.55 221.82 -855.5 -189.2 -50.62 -24.97  -20.5    540   1.01
# lp_parts[306] -156.8    9.59 222.83 -859.2 -190.3 -50.97 -25.01 -20.49    540   1.01
# lp_parts[307] -157.5    9.64 223.84 -863.0 -191.4 -51.32 -24.98 -20.49    540   1.01
# lp_parts[308] -158.2    9.68 224.86 -866.7 -192.4 -51.67  -25.0 -20.49    539   1.01
# lp_parts[309] -159.0    9.73 225.87 -870.4 -193.5 -52.02 -25.08 -20.49    539   1.01
# lp_parts[310] -159.7    9.78 226.88 -874.2 -194.6 -52.37 -25.16  -20.5    539   1.01
# lp_parts[311] -160.4    9.82 227.89 -877.9 -195.7 -52.72 -25.23 -20.49    538   1.01
# lp_parts[312] -161.2    9.87 228.91 -881.7 -196.8 -53.08 -25.25 -20.49    538   1.01
# lp_parts[313] -161.9    9.91 229.92 -885.4 -197.9 -53.44 -25.17 -20.49    538   1.01
# lp_parts[314] -162.7    9.96 230.93 -889.1 -199.0 -53.79 -25.08 -20.49    538   1.01
# lp_parts[315] -163.4   10.01 231.95 -892.9 -200.0 -54.15 -24.99  -20.5    537   1.01
# lp_parts[316] -164.1   10.05 232.96 -896.6 -201.1 -54.51 -24.98  -20.5    537   1.01
# lp_parts[317] -164.9    10.1 233.97 -900.4 -202.2 -54.87 -24.95 -20.51    537   1.01
# lp_parts[318] -165.6   10.14 234.99 -904.1 -203.3 -55.23 -24.96 -20.52    537   1.01
# lp_parts[319] -166.4   10.19  236.0 -907.9 -204.4  -55.6 -25.04 -20.51    536   1.01
# lp_parts[320] -167.1   10.24 237.01 -911.6 -205.5 -55.96 -25.07 -20.51    536   1.01
# lp_parts[321] -167.9   10.28 238.03 -915.4 -206.6 -56.33  -25.1 -20.51    536   1.01
# lp_parts[322] -168.6   10.33 239.04 -919.1 -207.7 -56.69 -25.18  -20.5    536   1.01
# lp_parts[323] -169.4   10.37 240.06 -922.9 -208.8 -57.06 -25.13 -20.49    535   1.01
# lp_parts[324] -170.1   10.42 241.07 -926.7 -209.9 -57.43 -25.04 -20.49    535   1.01
# lp_parts[325] -170.9   10.47 242.08 -930.4 -211.0  -57.8 -24.97 -20.49    535   1.01
# lp_parts[326] -171.7   10.51  243.1 -934.2 -212.1 -58.17 -24.91 -20.49    535   1.01
# lp_parts[327] -172.4   10.56 244.11 -937.9 -213.2 -58.54 -25.02 -20.49    535   1.01
# lp_parts[328] -173.2    10.6 245.13 -941.7 -214.3 -58.92 -25.04 -20.49    534   1.01
# lp_parts[329] -173.9   10.65 246.14 -945.5 -215.4 -59.29 -25.01 -20.49    534   1.01
# lp_parts[330] -174.7    10.7 247.16 -949.2 -216.5 -59.67 -24.98 -20.49    534   1.01
# lp_parts[331] -175.4   10.74 248.17 -953.0 -217.6 -60.04 -24.94 -20.48    534   1.01
# lp_parts[332] -176.2   10.79 249.19 -956.7 -218.7 -60.42  -25.0 -20.48    533   1.01
# lp_parts[333] -177.0   10.83  250.2 -960.5 -219.8  -60.8 -24.96 -20.48    533   1.01
# lp_parts[334] -177.7   10.88 251.22 -964.3 -221.0 -61.18 -24.92 -20.47    533   1.01
# lp_parts[335] -178.5   10.93 252.23 -968.0 -222.1 -61.56 -24.99 -20.47    533   1.01
# lp_parts[336] -179.3   10.97 253.25 -971.8 -223.2 -61.94 -24.93 -20.46    533   1.01
# lp_parts[337] -180.0   11.02 254.26 -975.6 -224.3 -62.32 -24.88 -20.46    532   1.01
# lp_parts[338] -180.8   11.07 255.28 -979.4 -225.4 -62.71 -24.87 -20.45    532   1.01
# lp_parts[339] -181.6   11.11 256.29 -983.1 -226.5 -63.09 -24.88 -20.45    532   1.01
# lp_parts[340] -182.3   11.16 257.31 -986.9 -227.6 -63.48 -24.94 -20.45    532   1.01
# lp_parts[341] -183.1    11.2 258.33 -990.7 -228.8 -63.87 -24.99 -20.45    532   1.01
# lp_parts[342] -183.9   11.25 259.34 -994.5 -229.9 -64.25 -25.04 -20.45    531   1.01
# lp_parts[343] -184.7    11.3 260.36 -998.2 -231.0 -64.64  -25.0 -20.46    531   1.01
# lp_parts[344] -185.4   11.34 261.37  -1002 -232.1 -65.03 -25.02 -20.46    531   1.01
# lp_parts[345] -186.2   11.39 262.39  -1005 -233.2 -65.42 -24.94 -20.45    531   1.01
# lp_parts[346] -187.0   11.44 263.41  -1009 -234.4 -65.81  -25.0 -20.45    531   1.01
# lp_parts[347] -187.8   11.48 264.42  -1013 -235.5 -66.21 -25.08 -20.45    530   1.01
# lp_parts[348] -188.5   11.53 265.44  -1017 -236.6  -66.6 -25.05 -20.46    530   1.01
# lp_parts[349] -189.3   11.57 266.46  -1020 -237.7 -66.99 -25.12 -20.46    530   1.01
# lp_parts[350] -190.1   11.62 267.47  -1024 -238.9 -67.39 -25.17 -20.46    530   1.01
# lp_parts[351] -190.9   11.67 268.49  -1028 -240.0 -67.79 -25.25 -20.46    530   1.01
# lp_parts[352] -191.7   11.71 269.51  -1032 -241.1 -68.18 -25.27 -20.46    529   1.01
# lp_parts[353] -192.4   11.76 270.52  -1036 -242.2 -68.58 -25.33 -20.47    529   1.01
# lp_parts[354] -193.2   11.81 271.54  -1039 -243.4 -68.98 -25.43 -20.47    529   1.01
# lp_parts[355] -194.0   11.85 272.56  -1043 -244.5 -69.38 -25.51 -20.47    529   1.01
# lp_parts[356] -194.8    11.9 273.57  -1047 -245.6 -69.78  -25.5 -20.47    529   1.01
# lp_parts[357] -195.6   11.94 274.59  -1051 -246.8 -70.18 -25.59 -20.47    529   1.01
# lp_parts[358] -196.4   11.99 275.61  -1055 -247.9 -70.59 -25.69 -20.47    528   1.01
# lp_parts[359] -197.2   12.04 276.62  -1058 -249.0 -70.99 -25.75 -20.46    528   1.01
# lp_parts[360] -198.0   12.08 277.64  -1062 -250.2 -71.39  -25.8 -20.46    528   1.01
# lp_parts[361] -198.7   12.13 278.66  -1066 -251.3  -71.8 -25.85 -20.46    528   1.01
# lp_parts[362] -199.5   12.18 279.68  -1070 -252.4 -72.21 -25.96 -20.46    528   1.01
# lp_parts[363] -200.3   12.22 280.69  -1074 -253.6 -72.61 -25.98 -20.47    527   1.01
# lp_parts[364] -201.1   12.27 281.71  -1077 -254.7 -73.02 -26.09 -20.46    527   1.01
# lp_parts[365] -201.9   12.31 282.73  -1081 -255.9 -73.43 -26.17 -20.46    527   1.01
# lp_parts[366] -202.7   12.36 283.75  -1085 -257.0 -73.84 -26.28 -20.46    527   1.01
# lp_parts[367] -203.5   12.41 284.76  -1089 -258.1 -74.25 -26.37 -20.46    527   1.01
# lp_parts[368] -204.3   12.45 285.78  -1092 -259.3 -74.66 -26.46 -20.46    527   1.01
# lp_parts[369] -205.1    12.5  286.8  -1096 -260.4 -75.07 -26.43 -20.46    526   1.01
# lp_parts[370] -205.9   12.55 287.82  -1100 -261.6 -75.49 -26.52 -20.46    526   1.01
# lp_parts[371] -206.7   12.59 288.84  -1104 -262.7  -75.9 -26.59 -20.47    526   1.01
# lp_parts[372] -207.5   12.64 289.85  -1108 -263.9 -76.32 -26.61 -20.47    526   1.01
# lp_parts[373] -208.3   12.69 290.87  -1111 -265.0 -76.73 -26.52 -20.47    526   1.01
# lp_parts[374] -209.1   12.73 291.89  -1115 -266.2 -77.15 -26.43 -20.47    526   1.01
# lp_parts[375] -209.9   12.78 292.91  -1119 -267.3 -77.57 -26.35 -20.48    525   1.01
# lp_parts[376] -210.7   12.82 293.93  -1123 -268.5 -77.98 -26.26 -20.48    525   1.01
# lp_parts[377] -211.5   12.87 294.94  -1127 -269.6  -78.4 -26.17 -20.48    525   1.01
# lp_parts[378] -212.3   12.92 295.96  -1131 -270.8 -78.82 -26.09 -20.48    525   1.01
# lp_parts[379] -213.1   12.96 296.98  -1134 -271.9 -79.24  -26.0 -20.49    525   1.01
# lp_parts[380] -213.9   13.01  298.0  -1138 -273.1 -79.67 -25.92 -20.48    525   1.01
# lp_parts[381] -214.7   13.06 299.02  -1142 -274.2 -80.09 -25.84 -20.48    525   1.01
# lp_parts[382] -215.5    13.1 300.04  -1146 -275.4 -80.51 -25.75 -20.48    524   1.01
# lp_parts[383] -216.3   13.15 301.06  -1150 -276.5 -80.93 -25.67 -20.48    524   1.01
# lp_parts[384] -217.1    13.2 302.07  -1153 -277.7 -81.36 -25.59 -20.47    524   1.01
# lp_parts[385] -218.0   13.24 303.09  -1157 -278.8 -81.78 -25.51 -20.48    524   1.01
# lp_parts[386] -218.8   13.29 304.11  -1161 -280.0 -82.21 -25.43 -20.48    524   1.01
# lp_parts[387] -219.6   13.33 305.13  -1165 -281.1 -82.64 -25.35 -20.48    524   1.01
# lp_parts[388] -220.4   13.38 306.15  -1169 -282.3 -83.06 -25.28 -20.48    523   1.01
# lp_parts[389] -221.2   13.43 307.17  -1172 -283.5 -83.49  -25.2 -20.48    523   1.01
# lp_parts[390] -222.0   13.47 308.19  -1176 -284.6 -83.92 -25.12 -20.48    523   1.01
# lp_parts[391] -222.8   13.52 309.21  -1180 -285.8 -84.35 -25.05 -20.48    523   1.01
# lp_parts[392] -223.6   13.57 310.23  -1184 -286.9 -84.78 -25.09 -20.48    523   1.01
# lp_parts[393] -224.5   13.61 311.25  -1188 -288.1 -85.21 -25.11 -20.48    523   1.01
# lp_parts[394] -225.3   13.66 312.26  -1192 -289.3 -85.65 -25.17 -20.47    523   1.01
# lp_parts[395] -226.1   13.71 313.28  -1195 -290.4 -86.08 -25.26 -20.47    523   1.01
# lp_parts[396] -226.9   13.75  314.3  -1199 -291.6 -86.51 -25.35 -20.47    522   1.01
# lp_parts[397] -227.7    13.8 315.32  -1203 -292.8 -86.95 -25.45 -20.47    522   1.01
# lp_parts[398] -228.6   13.84 316.34  -1207 -293.9 -87.38 -25.54 -20.47    522   1.01
# lp_parts[399] -229.4   13.89 317.36  -1211 -295.1 -87.82 -25.62 -20.46    522   1.01
# lp_parts[400] -230.2   13.94 318.38  -1214 -296.3 -88.25 -25.58 -20.47    522   1.01
# lp_parts[401] -231.0   13.98  319.4  -1218 -297.4 -88.69 -25.55 -20.47    522   1.01
# lp_parts[402] -231.8   14.03 320.42  -1222 -298.6 -89.13 -25.62 -20.47    522   1.01
# lp_parts[403] -232.7   14.08 321.44  -1226 -299.8 -89.57 -25.58 -20.48    521   1.01
# lp_parts[404] -233.5   14.12 322.46  -1230 -300.9 -90.01 -25.56 -20.48    521   1.01
# lp_parts[405] -234.3   14.17 323.48  -1234 -302.1 -90.45 -25.65 -20.49    521   1.01
# lp_parts[406] -235.1   14.22  324.5  -1237 -303.3 -90.89 -25.75 -20.49    521   1.01
# lp_parts[407] -236.0   14.26 325.52  -1241 -304.5 -91.33 -25.84  -20.5    521   1.01
# lp_parts[408] -236.8   14.31 326.54  -1245 -305.6 -91.77 -25.93  -20.5    521   1.01
# lp_parts[409] -237.6   14.36 327.56  -1249 -306.8 -92.21 -26.03 -20.51    521   1.01
# lp_parts[410] -238.4    14.4 328.58  -1253 -308.0 -92.66 -26.13  -20.5    521   1.01
# lp_parts[411] -239.3   14.45  329.6  -1257 -309.2  -93.1 -26.23  -20.5    520   1.01
# lp_parts[412] -240.1   14.49 330.62  -1260 -310.3 -93.55 -26.32  -20.5    520   1.01
# lp_parts[413] -240.9   14.54 331.64  -1264 -311.5 -93.99 -26.42 -20.49    520   1.01
# lp_parts[414] -241.8   14.59 332.66  -1268 -312.7 -94.44 -26.52  -20.5    520   1.01
# lp_parts[415] -242.6   14.63 333.68  -1272 -313.9 -94.88 -26.62  -20.5    520   1.01
# lp_parts[416] -243.4   14.68  334.7  -1276 -315.0 -95.33 -26.73 -20.51    520   1.01
# lp_parts[417] -244.3   14.73 335.72  -1280 -316.2 -95.78 -26.83 -20.51    520   1.01
# lp_parts[418] -245.1   14.77 336.74  -1283 -317.4 -96.23 -26.93 -20.52    520   1.01
# lp_parts[419] -245.9   14.82 337.76  -1287 -318.6 -96.68 -27.03 -20.53    519   1.01
# lp_parts[420] -246.8   14.87 338.78  -1291 -319.8 -97.13 -27.14 -20.52    519   1.01
# lp_parts[421] -247.6   14.91  339.8  -1295 -320.9 -97.58 -27.24 -20.51    519   1.01
# lp_parts[422] -248.4   14.96 340.82  -1299 -322.1 -98.03 -27.35 -20.51    519   1.01
# lp_parts[423] -249.3   15.01 341.84  -1303 -323.3 -98.48 -27.45 -20.52    519   1.01
# lp_parts[424] -250.1   15.05 342.86  -1306 -324.5 -98.93 -27.56 -20.53    519   1.01
# lp_parts[425] -250.9    15.1 343.88  -1310 -325.7 -99.39 -27.67 -20.53    519   1.01
# lp_parts[426] -251.8   15.15  344.9  -1314 -326.9 -99.84 -27.77 -20.52    519   1.01
# lp_parts[427] -252.6   15.19 345.92  -1318 -328.0 -100.3 -27.88 -20.51    518   1.01
# lp_parts[428] -253.5   15.24 346.94  -1322 -329.2 -100.7 -27.99 -20.51    518   1.01
# lp_parts[429] -254.3   15.28 347.96  -1326 -330.4 -101.2  -28.1 -20.51    518   1.01
# lp_parts[430] -255.1   15.33 348.99  -1330 -331.6 -101.6 -28.21 -20.51    518   1.01
# lp_parts[431] -256.0   15.38 350.01  -1333 -332.8 -102.1 -28.32  -20.5    518   1.01
# lp_parts[432] -256.8   15.42 351.03  -1337 -334.0 -102.5 -28.43 -20.49    518   1.01
# lp_parts[433] -257.7   15.47 352.05  -1341 -335.2 -103.0 -28.55 -20.49    518   1.01
# lp_parts[434] -258.5   15.52 353.07  -1345 -336.4 -103.5 -28.66 -20.49    518   1.01
# lp_parts[435] -259.4   15.56 354.09  -1349 -337.5 -103.9 -28.77 -20.48    518   1.01
# lp_parts[436] -260.2   15.61 355.11  -1353 -338.7 -104.4 -28.89 -20.49    517   1.01
# lp_parts[437] -261.0   15.66 356.13  -1356 -339.9 -104.8  -29.0 -20.49    517   1.01
# lp_parts[438] -261.9    15.7 357.15  -1360 -341.1 -105.3 -29.12 -20.49    517   1.01
# lp_parts[439] -262.7   15.75 358.17  -1364 -342.3 -105.8 -29.23 -20.48    517   1.01
# lp_parts[440] -263.6    15.8 359.19  -1368 -343.5 -106.2 -29.35 -20.48    517   1.01
# lp_parts[441] -264.4   15.84 360.21  -1372 -344.7 -106.7 -29.46 -20.47    517   1.01
# lp_parts[442] -265.3   15.89 361.24  -1376 -345.9 -107.1 -29.58 -20.47    517   1.01
# lp_parts[443] -266.1   15.94 362.26  -1380 -347.1 -107.6  -29.7 -20.47    517   1.01
# lp_parts[444] -267.0   15.98 363.28  -1383 -348.3 -108.1 -29.82 -20.48    517   1.01
# lp_parts[445] -267.8   16.03  364.3  -1387 -349.5 -108.5 -29.94 -20.48    517   1.01
# lp_parts[446] -268.7   16.08 365.32  -1391 -350.7 -109.0 -30.06 -20.47    516   1.01
# lp_parts[447] -269.5   16.12 366.34  -1395 -351.9 -109.5 -30.18 -20.47    516   1.01
# lp_parts[448] -270.4   16.17 367.36  -1399 -353.1 -109.9  -30.3 -20.48    516   1.01
# lp_parts[449] -271.2   16.21 368.38  -1403 -354.3 -110.4 -30.42 -20.49    516   1.01
# lp_parts[450] -272.1   16.26 369.41  -1407 -355.5 -110.9 -30.54 -20.49    516   1.01
# lp_parts[451] -272.9   16.31 370.43  -1410 -356.7 -111.3 -30.67 -20.48    516   1.01
# lp_parts[452] -273.8   16.35 371.45  -1414 -357.9 -111.8 -30.79 -20.48    516   1.01
# lp_parts[453] -274.6    16.4 372.47  -1418 -359.1 -112.3 -30.91 -20.48    516   1.01
# lp_parts[454] -275.5   16.45 373.49  -1422 -360.3 -112.7 -31.04 -20.48    516   1.01
# lp_parts[455] -276.4   16.49 374.51  -1426 -361.5 -113.2 -31.16 -20.49    516   1.01
# lp_parts[456] -277.2   16.54 375.53  -1430 -362.7 -113.7 -31.29 -20.49    515   1.01
# lp_parts[457] -278.1   16.59 376.56  -1434 -363.9 -114.2 -31.41 -20.49    515   1.01
# lp_parts[458] -278.9   16.63 377.58  -1437 -365.1 -114.6 -31.54 -20.49    515   1.01
# lp_parts[459] -279.8   16.68  378.6  -1441 -366.3 -115.1 -31.67  -20.5    515   1.01
# lp_parts[460] -280.6   16.73 379.62  -1445 -367.5 -115.6 -31.79  -20.5    515   1.01
# lp_parts[461] -281.5   16.77 380.64  -1449 -368.7 -116.1 -31.92  -20.5    515   1.01
# lp_parts[462] -282.4   16.82 381.66  -1453 -369.9 -116.5 -32.05  -20.5    515   1.01
# lp_parts[463] -283.2   16.87 382.69  -1457 -371.1 -117.0 -32.18 -20.51    515   1.01
# lp_parts[464] -284.1   16.91 383.71  -1461 -372.3 -117.5 -32.31 -20.52    515   1.01
# lp_parts[465] -284.9   16.96 384.73  -1464 -373.5 -118.0 -32.44 -20.52    515   1.01
# lp_parts[466] -285.8   17.01 385.75  -1468 -374.7 -118.4 -32.57 -20.53    515   1.01
# lp_parts[467] -286.7   17.05 386.77  -1472 -375.9 -118.9  -32.7 -20.53    514   1.01
# lp_parts[468] -287.5    17.1 387.79  -1476 -377.1 -119.4 -32.83 -20.53    514   1.01
# lp_parts[469] -288.4   17.15 388.82  -1480 -378.4 -119.9 -32.96 -20.53    514   1.01
# lp_parts[470] -289.3   17.19 389.84  -1484 -379.6 -120.3  -33.1 -20.54    514   1.01
# lp_parts[471] -290.1   17.24 390.86  -1488 -380.8 -120.8 -33.23 -20.55    514   1.01
# lp_parts[472] -291.0   17.29 391.88  -1491 -382.0 -121.3 -33.36 -20.56    514   1.01
# lp_parts[473] -291.8   17.33  392.9  -1495 -383.2 -121.8  -33.5 -20.57    514   1.01
# lp_parts[474] -292.7   17.38 393.93  -1499 -384.4 -122.3 -33.63 -20.57    514   1.01
# lp_parts[475] -293.6   17.43 394.95  -1503 -385.6 -122.8 -33.77 -20.58    514   1.01
# lp_parts[476] -294.4   17.47 395.97  -1507 -386.8 -123.2  -33.9  -20.6    514   1.01
# lp_parts[477] -295.3   17.52 396.99  -1511 -388.0 -123.7 -34.04 -20.61    514   1.01
# lp_parts[478] -296.2   17.56 398.01  -1515 -389.3 -124.2 -34.18 -20.61    513   1.01
# lp_parts[479] -297.0   17.61 399.04  -1519 -390.5 -124.7 -34.32 -20.61    513   1.01
# lp_parts[480] -297.9   17.66 400.06  -1522 -391.7 -125.2 -34.45 -20.62    513   1.01
# lp_parts[481] -298.8    17.7 401.08  -1526 -392.9 -125.6 -34.59 -20.62    513   1.01
# lp_parts[482] -299.7   17.75  402.1  -1530 -394.1 -126.1 -34.73 -20.61    513   1.01
# lp_parts[483] -300.5    17.8 403.12  -1534 -395.3 -126.6 -34.87 -20.62    513   1.01
# lp_parts[484] -301.4   17.84 404.15  -1538 -396.6 -127.1 -35.01 -20.63    513   1.01
# lp_parts[485] -302.3   17.89 405.17  -1542 -397.8 -127.6 -35.15 -20.64    513   1.01
# ...
# prob_n[319]   1.3e-3  1.0e-4 3.2e-3    0.06.5e-821.5e-17 1.4e-4   0.01   1000    1.0
# prob_n[320]   1.3e-3  1.0e-4 3.2e-3    0.02.2e-821.0e-17 1.5e-4   0.01    996    1.0
# prob_n[321]   1.3e-3  1.0e-4 3.2e-3    0.07.2e-837.1e-18 1.4e-4   0.01    992    1.0
# prob_n[322]   1.3e-3  1.0e-4 3.2e-3    0.02.4e-834.9e-18 1.2e-4   0.01    987    1.0
# prob_n[323]   1.3e-3  1.0e-4 3.2e-3    0.08.0e-843.4e-18 1.3e-4   0.01    983    1.0
# prob_n[324]   1.3e-3  1.0e-4 3.2e-3    0.02.7e-842.4e-18 1.2e-4   0.01    975    1.0
# prob_n[325]   1.3e-3  1.0e-4 3.2e-3    0.08.9e-851.6e-18 1.2e-4   0.01    967    1.0
# prob_n[326]   1.3e-3  1.0e-4 3.2e-3    0.03.0e-851.1e-18 1.3e-4   0.01    959    1.0
# prob_n[327]   1.3e-3  1.1e-4 3.2e-3    0.09.8e-867.7e-19 1.4e-4   0.01    951    1.0
# prob_n[328]   1.3e-3  1.1e-4 3.3e-3    0.03.3e-865.3e-19 1.5e-4   0.01    943    1.0
# prob_n[329]   1.3e-3  1.1e-4 3.3e-3    0.01.1e-863.7e-19 1.4e-4   0.01    935    1.0
# prob_n[330]   1.3e-3  1.1e-4 3.3e-3    0.03.6e-872.5e-19 1.3e-4   0.01    927    1.0
# prob_n[331]   1.3e-3  1.1e-4 3.3e-3    0.01.2e-871.7e-19 1.3e-4   0.01    919    1.0
# prob_n[332]   1.4e-3  1.1e-4 3.3e-3    0.03.9e-881.2e-19 1.4e-4   0.01    911    1.0
# prob_n[333]   1.4e-3  1.1e-4 3.3e-3    0.01.3e-888.1e-20 1.4e-4   0.01    903    1.0
# prob_n[334]   1.4e-3  1.1e-4 3.3e-3    0.04.2e-895.6e-20 1.4e-4   0.01    895    1.0
# prob_n[335]   1.4e-3  1.1e-4 3.3e-3    0.01.4e-893.8e-20 1.4e-4   0.01    887    1.0
# prob_n[336]   1.4e-3  1.1e-4 3.3e-3    0.04.6e-902.6e-20 1.5e-4   0.01    879    1.0
# prob_n[337]   1.4e-3  1.1e-4 3.3e-3    0.01.5e-901.8e-20 1.4e-4   0.01    872    1.0
# prob_n[338]   1.4e-3  1.1e-4 3.3e-3    0.04.9e-911.2e-20 1.5e-4   0.01    864    1.0
# prob_n[339]   1.4e-3  1.1e-4 3.3e-3    0.01.6e-918.2e-21 1.5e-4   0.01    856    1.0
# prob_n[340]   1.4e-3  1.1e-4 3.3e-3    0.05.3e-925.6e-21 1.6e-4   0.01    849    1.0
# prob_n[341]   1.4e-3  1.1e-4 3.3e-3    0.01.7e-923.8e-21 1.6e-4   0.01    841    1.0
# prob_n[342]   1.4e-3  1.1e-4 3.3e-3    0.05.6e-932.6e-21 1.5e-4   0.01    834    1.0
# prob_n[343]   1.4e-3  1.1e-4 3.3e-3    0.01.8e-931.8e-21 1.4e-4   0.01    826    1.0
# prob_n[344]   1.4e-3  1.1e-4 3.3e-3    0.06.0e-941.2e-21 1.4e-4   0.01    819    1.0
# prob_n[345]   1.4e-3  1.1e-4 3.3e-3    0.02.0e-948.0e-22 1.4e-4   0.01    812    1.0
# prob_n[346]   1.4e-3  1.2e-4 3.3e-3    0.06.4e-955.4e-22 1.4e-4   0.01    805    1.0
# prob_n[347]   1.4e-3  1.2e-4 3.3e-3    0.02.1e-953.7e-22 1.5e-4   0.01    798    1.0
# prob_n[348]   1.4e-3  1.2e-4 3.3e-3    0.06.7e-962.5e-22 1.4e-4   0.01    791    1.0
# prob_n[349]   1.4e-3  1.2e-4 3.3e-3    0.02.2e-961.7e-22 1.4e-4   0.01    785    1.0
# prob_n[350]   1.4e-3  1.2e-4 3.3e-3    0.07.1e-971.1e-22 1.3e-4   0.01    778    1.0
# prob_n[351]   1.4e-3  1.2e-4 3.3e-3    0.02.3e-977.6e-23 1.3e-4   0.01    772    1.0
# prob_n[352]   1.4e-3  1.2e-4 3.2e-3    0.07.4e-985.1e-23 1.2e-4   0.01    765    1.0
# prob_n[353]   1.4e-3  1.2e-4 3.2e-3    0.02.4e-983.4e-23 1.2e-4   0.01    759    1.0
# prob_n[354]   1.4e-3  1.2e-4 3.2e-3    0.07.8e-992.3e-23 1.1e-4   0.01    753    1.0
# prob_n[355]   1.4e-3  1.2e-4 3.2e-3    0.02.5e-991.5e-23 9.9e-5   0.01    747    1.0
# prob_n[356]   1.4e-3  1.2e-4 3.2e-3    0.08.1e-1001.0e-23 9.9e-5   0.01    741    1.0
# prob_n[357]   1.4e-3  1.2e-4 3.2e-3    0.02.6e-1006.9e-24 9.1e-5   0.01    735    1.0
# prob_n[358]   1.3e-3  1.2e-4 3.2e-3    0.08.4e-1014.6e-24 8.3e-5   0.01    730    1.0
# prob_n[359]   1.3e-3  1.2e-4 3.2e-3    0.02.7e-1013.1e-24 7.9e-5   0.01    724   1.01
# prob_n[360]   1.3e-3  1.2e-4 3.2e-3    0.08.6e-1022.1e-24 7.7e-5   0.01    718   1.01
# prob_n[361]   1.3e-3  1.2e-4 3.2e-3    0.02.8e-1021.4e-24 7.0e-5   0.01    713   1.01
# prob_n[362]   1.3e-3  1.2e-4 3.2e-3    0.08.9e-1039.2e-25 6.9e-5   0.01    707   1.01
# prob_n[363]   1.3e-3  1.2e-4 3.2e-3    0.02.9e-1036.1e-25 6.2e-5   0.01    702   1.01
# prob_n[364]   1.3e-3  1.2e-4 3.2e-3    0.09.1e-1044.1e-25 5.7e-5   0.01    697   1.01
# prob_n[365]   1.3e-3  1.2e-4 3.1e-3    0.02.9e-1042.7e-25 5.2e-5   0.01    692   1.01
# prob_n[366]   1.3e-3  1.2e-4 3.1e-3    0.09.3e-1051.8e-25 5.0e-5   0.01    687   1.01
# prob_n[367]   1.3e-3  1.2e-4 3.1e-3    0.03.0e-1051.2e-25 5.0e-5   0.01    682   1.01
# prob_n[368]   1.3e-3  1.2e-4 3.1e-3    0.09.5e-1067.9e-26 4.6e-5   0.01    677   1.01
# prob_n[369]   1.3e-3  1.2e-4 3.1e-3    0.03.0e-1065.2e-26 4.8e-5   0.01    672   1.01
# prob_n[370]   1.3e-3  1.2e-4 3.1e-3    0.09.7e-1073.5e-26 5.2e-5   0.01    667   1.01
# prob_n[371]   1.3e-3  1.2e-4 3.1e-3    0.03.1e-1072.3e-26 5.7e-5   0.01    662   1.01
# prob_n[372]   1.3e-3  1.2e-4 3.1e-3    0.09.8e-1081.5e-26 6.3e-5   0.01    658   1.01
# prob_n[373]   1.3e-3  1.2e-4 3.0e-3    0.03.1e-10810.0e-27 6.8e-5   0.01    653   1.01
# prob_n[374]   1.3e-3  1.2e-4 3.0e-3    0.09.9e-1096.6e-27 7.5e-5   0.01    649   1.01
# prob_n[375]   1.3e-3  1.2e-4 3.0e-3    0.03.1e-1094.3e-27 8.2e-5   0.01    644   1.01
# prob_n[376]   1.3e-3  1.2e-4 3.0e-3    0.09.9e-1102.9e-27 8.9e-5   0.01    640   1.01
# prob_n[377]   1.3e-3  1.2e-4 3.0e-3    0.03.1e-1101.9e-27 9.7e-5   0.01    636   1.01
# prob_n[378]   1.3e-3  1.2e-4 3.0e-3    0.09.9e-1111.2e-27 1.1e-4   0.01    632   1.01
# prob_n[379]   1.3e-3  1.2e-4 3.0e-3    0.03.1e-1118.1e-28 1.2e-4   0.01    628   1.01
# prob_n[380]   1.3e-3  1.2e-4 3.0e-3    0.09.9e-1125.3e-28 1.3e-4   0.01    624   1.01
# prob_n[381]   1.3e-3  1.2e-4 2.9e-3    0.03.1e-1123.5e-28 1.4e-4   0.01    620   1.01
# prob_n[382]   1.3e-3  1.2e-4 2.9e-3    0.09.9e-1132.3e-28 1.5e-4   0.01    616   1.01
# prob_n[383]   1.2e-3  1.2e-4 2.9e-3    0.03.1e-1131.5e-28 1.6e-4   0.01    613   1.01
# prob_n[384]   1.2e-3  1.2e-4 2.9e-3    0.09.8e-1149.8e-29 1.7e-4   0.01    609   1.01
# prob_n[385]   1.2e-3  1.2e-4 2.9e-3    0.03.1e-1146.4e-29 1.9e-4   0.01    606   1.01
# prob_n[386]   1.2e-3  1.2e-4 2.9e-3    0.09.7e-1154.2e-29 2.0e-4   0.01    603   1.01
# prob_n[387]   1.2e-3  1.2e-4 2.9e-3    0.03.1e-1152.7e-29 2.1e-4   0.01    600   1.01
# prob_n[388]   1.2e-3  1.2e-4 2.9e-3    0.09.6e-1161.8e-29 2.1e-4   0.01    597   1.01
# prob_n[389]   1.2e-3  1.2e-4 2.8e-3    0.03.0e-1161.2e-29 2.0e-4   0.01    594   1.01
# prob_n[390]   1.2e-3  1.2e-4 2.8e-3    0.09.4e-1177.6e-30 1.8e-4   0.01    591   1.01
# prob_n[391]   1.2e-3  1.2e-4 2.8e-3    0.03.0e-1174.9e-30 1.7e-4   0.01    588   1.01
# prob_n[392]   1.2e-3  1.2e-4 2.8e-3    0.09.2e-1183.2e-30 1.6e-4   0.01    586   1.01
# prob_n[393]   1.2e-3  1.2e-4 2.8e-3    0.02.9e-1182.1e-30 1.7e-4   0.01    584   1.01
# prob_n[394]   1.2e-3  1.2e-4 2.8e-3    0.09.0e-1191.4e-30 1.7e-4   0.01    582   1.01
# prob_n[395]   1.2e-3  1.2e-4 2.8e-3    0.02.8e-1198.8e-31 1.8e-4   0.01    580   1.01
# prob_n[396]   1.2e-3  1.2e-4 2.8e-3    0.08.8e-1205.7e-31 1.7e-4   0.01    578   1.01
# prob_n[397]   1.2e-3  1.1e-4 2.8e-3    0.02.7e-1203.7e-31 1.6e-4   0.01    576   1.01
# prob_n[398]   1.2e-3  1.1e-4 2.7e-3    0.08.6e-1212.4e-31 1.5e-4   0.01    575   1.01
# prob_n[399]   1.2e-3  1.1e-4 2.7e-3    0.02.7e-1211.5e-31 1.3e-4   0.01    574   1.01
# prob_n[400]   1.2e-3  1.1e-4 2.7e-3    0.08.3e-1221.0e-31 1.2e-4   0.01    572   1.01
# prob_n[401]   1.2e-3  1.1e-4 2.7e-3    0.02.6e-1226.5e-32 1.1e-4   0.01    571   1.01
# prob_n[402]   1.2e-3  1.1e-4 2.7e-3    0.08.0e-1234.2e-32 1.0e-4   0.01    571   1.01
# prob_n[403]   1.2e-3  1.1e-4 2.7e-3    0.02.5e-1232.7e-32 9.2e-5   0.01    568   1.01
# prob_n[404]   1.1e-3  1.1e-4 2.7e-3    0.07.7e-1241.7e-32 8.4e-5   0.01    566   1.01
# prob_n[405]   1.1e-3  1.1e-4 2.7e-3    0.02.4e-1241.1e-32 7.7e-5   0.01    565   1.01
# prob_n[406]   1.1e-3  1.1e-4 2.7e-3    0.07.4e-1257.2e-33 7.0e-5   0.01    563   1.01
# prob_n[407]   1.1e-3  1.1e-4 2.7e-3    0.02.3e-1254.6e-33 6.3e-5   0.01    562   1.01
# prob_n[408]   1.1e-3  1.1e-4 2.7e-3    0.07.1e-1263.0e-33 5.8e-5   0.01    560   1.01
# prob_n[409]   1.1e-3  1.1e-4 2.7e-3    0.02.2e-1261.9e-33 5.2e-510.0e-3    559   1.01
# prob_n[410]   1.1e-3  1.1e-4 2.7e-3    0.06.8e-1271.2e-33 4.7e-510.0e-3    558   1.01
# prob_n[411]   1.1e-3  1.1e-4 2.6e-3    0.02.1e-1277.9e-34 4.3e-5 9.9e-3    557   1.01
# prob_n[412]   1.1e-3  1.1e-4 2.6e-3    0.06.5e-1285.1e-34 3.9e-510.0e-3    556   1.01
# prob_n[413]   1.1e-3  1.1e-4 2.6e-3    0.02.0e-1283.3e-34 3.5e-510.0e-3    555   1.01
# prob_n[414]   1.1e-3  1.1e-4 2.6e-3    0.06.2e-1292.1e-34 3.2e-510.0e-3    555   1.01
# prob_n[415]   1.1e-3  1.1e-4 2.6e-3    0.01.9e-1291.3e-34 2.9e-510.0e-3    554   1.01
# prob_n[416]   1.1e-3  1.1e-4 2.6e-3    0.05.8e-1308.5e-35 2.6e-5 9.9e-3    553   1.01
# prob_n[417]   1.1e-3  1.1e-4 2.6e-3    0.01.8e-1305.4e-35 2.4e-5 9.8e-3    552   1.01
# prob_n[418]   1.1e-3  1.1e-4 2.6e-3    0.05.5e-1313.5e-35 2.1e-5 9.8e-3    550   1.01
# prob_n[419]   1.1e-3  1.1e-4 2.6e-3    0.01.7e-1312.2e-35 1.9e-5 9.7e-3    549   1.01
# prob_n[420]   1.1e-3  1.1e-4 2.6e-3    0.05.2e-1321.4e-35 1.7e-5 9.7e-3    547   1.01
# prob_n[421]   1.1e-3  1.1e-4 2.6e-3    0.01.6e-1329.0e-36 1.6e-5 9.8e-3    545   1.01
# prob_n[422]   1.1e-3  1.1e-4 2.6e-3    0.04.9e-1335.8e-36 1.4e-5 9.8e-3    542   1.01
# prob_n[423]   1.1e-3  1.1e-4 2.6e-3    0.01.5e-1333.7e-36 1.3e-5 9.8e-3    539   1.01
# prob_n[424]   1.1e-3  1.1e-4 2.6e-3    0.04.6e-1342.3e-36 1.1e-5 9.7e-3    536   1.01
# prob_n[425]   1.1e-3  1.1e-4 2.6e-3    0.01.4e-1341.5e-36 1.0e-5 9.8e-3    532   1.01
# prob_n[426]   1.1e-3  1.1e-4 2.6e-3    0.04.3e-1359.4e-37 9.1e-6 9.8e-3    527   1.01
# prob_n[427]   1.1e-3  1.1e-4 2.6e-3    0.01.3e-1356.0e-37 8.2e-6 9.9e-3    521   1.01
# prob_n[428]   1.1e-3  1.2e-4 2.6e-3    0.04.0e-1363.8e-37 7.3e-6 9.9e-3    516   1.01
# prob_n[429]   1.1e-3  1.2e-4 2.6e-3    0.01.2e-1362.4e-37 6.6e-6 9.9e-3    509   1.01
# prob_n[430]   1.1e-3  1.2e-4 2.6e-3    0.03.7e-1371.5e-37 5.9e-6   0.01    502   1.01
# prob_n[431]   1.1e-3  1.2e-4 2.6e-3    0.01.1e-1379.7e-38 5.3e-6   0.01    494   1.01
# prob_n[432]   1.1e-3  1.2e-4 2.6e-3    0.03.5e-1386.1e-38 4.7e-6   0.01    485   1.01
# prob_n[433]   1.1e-3  1.2e-4 2.7e-3    0.01.1e-1383.9e-38 4.2e-6   0.01    476   1.01
# prob_n[434]   1.1e-3  1.3e-4 2.7e-3    0.03.2e-1392.5e-38 3.8e-6   0.01    452   1.01
# prob_n[435]   1.1e-3  1.3e-4 2.7e-3    0.09.8e-1401.6e-38 3.4e-6   0.01    427   1.01
# prob_n[436]   1.1e-3  1.3e-4 2.7e-3    0.03.0e-1409.8e-39 3.0e-6   0.01    402   1.01
# prob_n[437]   1.1e-3  1.4e-4 2.7e-3    0.09.1e-1416.2e-39 2.7e-6   0.01    378   1.01
# prob_n[438]   1.1e-3  1.4e-4 2.7e-3    0.02.7e-1413.9e-39 2.4e-6   0.01    354   1.01
# prob_n[439]   1.1e-3  1.5e-4 2.7e-3    0.08.3e-1422.5e-39 2.1e-6   0.01    331   1.01
# prob_n[440]   1.1e-3  1.5e-4 2.7e-3    0.02.5e-1421.5e-39 1.9e-6   0.01    309   1.01
# prob_n[441]   1.1e-3  1.6e-4 2.7e-3    0.07.7e-1439.8e-40 1.7e-6   0.01    289   1.01
# prob_n[442]   1.1e-3  1.7e-4 2.7e-3    0.02.3e-1436.1e-40 1.5e-6   0.01    270   1.01
# prob_n[443]   1.1e-3  1.7e-4 2.8e-3    0.07.0e-1443.9e-40 1.3e-6   0.01    252   1.01
# prob_n[444]   1.1e-3  1.8e-4 2.8e-3    0.02.1e-1442.4e-40 1.2e-6   0.01    235   1.01
# prob_n[445]   1.1e-3  1.9e-4 2.8e-3    0.06.4e-1451.5e-40 1.0e-6   0.01    220   1.01
# prob_n[446]   1.1e-3  2.0e-4 2.8e-3    0.01.9e-1459.6e-41 9.3e-7   0.01    208   1.01
# prob_n[447]   1.1e-3  2.0e-4 2.8e-3    0.05.9e-1466.0e-41 8.2e-7   0.01    196   1.01
# prob_n[448]   1.1e-3  2.1e-4 2.9e-3    0.01.8e-1463.8e-41 7.3e-7   0.01    186   1.01
# prob_n[449]   1.2e-3  2.2e-4 2.9e-3    0.05.3e-1472.4e-41 6.5e-7   0.01    175   1.02
# prob_n[450]   1.2e-3  2.3e-4 2.9e-3    0.01.6e-1471.5e-41 5.7e-7   0.01    166   1.02
# prob_n[451]   1.2e-3  2.3e-4 2.9e-3    0.04.9e-1489.3e-42 5.1e-7   0.01    157   1.02
# prob_n[452]   1.2e-3  2.4e-4 3.0e-3    0.01.5e-1485.8e-42 4.5e-7   0.01    150   1.02
# prob_n[453]   1.2e-3  2.5e-4 3.0e-3    0.04.4e-1493.6e-42 4.0e-7   0.01    142   1.02
# prob_n[454]   1.2e-3  2.6e-4 3.0e-3    0.01.3e-1492.3e-42 3.5e-7   0.01    136   1.02
# prob_n[455]   1.2e-3  2.7e-4 3.0e-3    0.04.0e-1501.4e-42 3.1e-7   0.01    130   1.02
# prob_n[456]   1.2e-3  2.8e-4 3.1e-3    0.01.2e-1508.9e-43 2.7e-7   0.01    125   1.02
# prob_n[457]   1.2e-3  2.8e-4 3.1e-3    0.03.6e-1515.5e-43 2.4e-7   0.01    119   1.02
# prob_n[458]   1.2e-3  2.9e-4 3.1e-3    0.01.1e-1513.5e-43 2.1e-7   0.01    114   1.03
# prob_n[459]   1.2e-3  3.0e-4 3.2e-3    0.03.2e-1522.2e-43 1.9e-7   0.01    110   1.03
# prob_n[460]   1.2e-3  3.1e-4 3.2e-3    0.09.7e-1531.3e-43 1.6e-7   0.01    106   1.03
# prob_n[461]   1.2e-3  3.2e-4 3.3e-3    0.02.9e-1538.4e-44 1.4e-7   0.01    102   1.03
# prob_n[462]   1.2e-3  3.3e-4 3.3e-3    0.08.7e-1545.2e-44 1.3e-7   0.01     98   1.03
# prob_n[463]   1.2e-3  3.4e-4 3.3e-3    0.02.6e-1543.2e-44 1.1e-7   0.01     95   1.03
# prob_n[464]   1.2e-3  3.5e-4 3.4e-3    0.07.8e-1552.0e-44 9.8e-8   0.01     92   1.04
# prob_n[465]   1.2e-3  3.6e-4 3.4e-3    0.02.3e-1551.3e-44 8.6e-8   0.01     89   1.04
# prob_n[466]   1.3e-3  3.8e-4 3.5e-3    0.07.0e-1567.8e-45 7.5e-8   0.01     86   1.04
# prob_n[467]   1.3e-3  3.9e-4 3.5e-3    0.02.1e-1564.8e-45 6.6e-8   0.01     83   1.04
# prob_n[468]   1.3e-3  4.0e-4 3.6e-3    0.06.2e-1573.0e-45 5.8e-8   0.01     81   1.04
# prob_n[469]   1.3e-3  4.1e-4 3.6e-3    0.01.9e-1571.9e-45 5.1e-8   0.01     79   1.04
# prob_n[470]   1.3e-3  4.2e-4 3.7e-3    0.05.5e-1581.2e-45 4.5e-8   0.01     77   1.05
# prob_n[471]   1.3e-3  4.3e-4 3.7e-3    0.01.7e-1587.1e-46 3.9e-8   0.01     75   1.05
# prob_n[472]   1.3e-3  4.4e-4 3.8e-3    0.04.9e-1594.4e-46 3.4e-8   0.02     73   1.05
# prob_n[473]   1.3e-3  4.5e-4 3.8e-3    0.01.5e-1592.7e-46 3.0e-8   0.02     71   1.05
# prob_n[474]   1.3e-3  4.7e-4 3.9e-3    0.04.4e-1601.7e-46 2.6e-8   0.02     70   1.05
# prob_n[475]   1.3e-3  4.8e-4 3.9e-3    0.01.3e-1601.0e-46 2.3e-8   0.02     68   1.05
# prob_n[476]   1.3e-3  4.9e-4 4.0e-3    0.03.9e-1616.5e-47 2.0e-8   0.02     67   1.05
# prob_n[477]   1.3e-3  5.0e-4 4.1e-3    0.01.1e-1614.0e-47 1.7e-8   0.02     65   1.06
# prob_n[478]   1.4e-3  5.1e-4 4.1e-3    0.03.4e-1622.5e-47 1.5e-8   0.02     64   1.06
# prob_n[479]   1.4e-3  5.2e-4 4.2e-3    0.01.0e-1621.5e-47 1.3e-8   0.02     63   1.06
# prob_n[480]   1.4e-3  5.4e-4 4.2e-3    0.03.0e-1639.4e-48 1.1e-8   0.02     62   1.06
# prob_n[481]   1.4e-3  5.5e-4 4.3e-3    0.08.9e-1645.8e-4810.0e-9   0.02     61   1.06
# prob_n[482]   1.4e-3  5.6e-4 4.4e-3    0.02.6e-1643.6e-48 8.7e-9   0.02     60   1.06
# prob_n[483]   1.4e-3  5.7e-4 4.4e-3    0.07.8e-1652.2e-48 7.6e-9   0.02     59   1.06
# prob_n[484]   1.4e-3  5.8e-4 4.5e-3    0.02.3e-1651.4e-48 6.6e-9   0.02     59   1.07
# prob_n[485]   1.4e-3  6.0e-4 4.5e-3    0.06.9e-1668.3e-49 5.7e-9   0.02     58   1.07
# prob_n[486]   1.4e-3  6.1e-4 4.6e-3    0.02.0e-1665.1e-49 5.0e-9   0.02     57   1.07
# prob_n[487]   1.4e-3  6.2e-4 4.7e-3    0.06.0e-1673.1e-49 4.3e-9   0.02     57   1.07
# prob_n[488]   1.4e-3  6.3e-4 4.7e-3    0.01.8e-1671.9e-49 3.7e-9   0.02     56   1.07
# prob_n[489]   1.4e-3  6.4e-4 4.8e-3    0.05.2e-1681.2e-49 3.2e-9   0.02     55   1.07
# prob_n[490]   1.4e-3  6.5e-4 4.8e-3    0.01.6e-1687.3e-50 2.8e-9   0.02     55   1.07
# prob_n[491]   1.5e-3  6.7e-4 4.9e-3    0.04.6e-1694.5e-50 2.4e-9   0.02     54   1.07
# prob_n[492]   1.5e-3  6.8e-4 5.0e-3    0.01.4e-1692.7e-50 2.1e-9   0.02     54   1.07
# prob_n[493]   1.5e-3  6.9e-4 5.0e-3    0.04.0e-1701.7e-50 1.8e-9   0.02     54   1.07
# prob_n[494]   1.5e-3  7.0e-4 5.1e-3    0.01.2e-1701.0e-50 1.6e-9   0.02     53   1.08
# prob_n[495]   1.5e-3  7.1e-4 5.2e-3    0.03.5e-1716.3e-51 1.4e-9   0.02     53   1.08
# prob_n[496]   1.5e-3  7.2e-4 5.2e-3    0.01.0e-1713.9e-51 1.2e-9   0.02     52   1.08
# prob_n[497]   1.5e-3  7.3e-4 5.3e-3    0.03.0e-1722.4e-51 1.0e-9   0.02     52   1.08
# prob_n[498]   1.5e-3  7.4e-4 5.3e-3    0.08.8e-1731.4e-518.9e-10   0.02     52   1.08
# prob_n[499]   1.5e-3  7.5e-4 5.4e-3    0.02.6e-1738.8e-527.6e-10   0.03     52   1.08
# prob_n[500]   1.5e-3  7.6e-4 5.4e-3    0.07.6e-1745.4e-526.6e-10   0.03     51   1.08
# lp__           -19.2    0.03   0.47 -20.55 -19.27 -19.01 -18.91 -18.87    197   1.02
#
# Samples were drawn using NUTS at Mon Feb 24 19:36:21 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
plt.hist(fit['theta'])
plt.xlabel('Theta')
plt.ylabel('Number of Samples')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(fit['theta'], fit['n'], '.')
plt.xlabel('Theta')
plt.ylabel('Number of Samples')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# <p> Finally let us consider a coin tossing example from earlier, but in this case we will have run the experiment twice. We will then use data from both experiments to fit our head rates. <p>
#
# <br >

# %%
two_exp_rate = """// Inferring a Common Rate, With Posterior Predictive
data { 
  int<lower=1> n1; 
  int<lower=1> n2; 
  int<lower=0> k1;
  int<lower=0> k2;
}
parameters {
  real<lower=0,upper=1> theta;
} 
model {
  // Prior on Single Rate Theta
  theta ~ beta(1, 1);
  
  // Observed Counts
  k1 ~ binomial(n1, theta);
  k2 ~ binomial(n2, theta);
}"""

sm=pystan.StanModel(model_code=two_exp_rate_gen)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_bd8f6a5f874a46897ced59e716bf395f NOW.
# /home/philip/anaconda3/envs/machine_learning/lib/python3.6/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmptpd97gwr/stanfit4anon_model_bd8f6a5f874a46897ced59e716bf395f_7086301933803381241.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
data_1 = {
'k1': 4,
'k2': 6,
'n1': 10,
'n2': 10}

data_2 = {
'k1': 0,
'k2': 10,
'n1': 10,
'n2': 10}

# %%
fit1=sm.sampling(data=data_1,chains=4,iter=1000,seed=12329)


plt.hist(fit1['theta'])
plt.show()

fit2=sm.sampling(data=data_2,chains=4,iter=1000,seed=12329)


plt.hist(fit2['theta'])
plt.show()

# %%
two_exp_rate_gen = """// Inferring a Common Rate, With Posterior Predictive
data { 
  int<lower=1> n1; 
  int<lower=1> n2; 
  int<lower=0> k1;
  int<lower=0> k2;
}
parameters {
  real<lower=0,upper=1> theta;
} 
model {
  // Prior on Single Rate Theta
  theta ~ beta(1, 1);
  
  // Observed Counts
  k1 ~ binomial(n1, theta);
  k2 ~ binomial(n2, theta);
}
generated quantities {
  int<lower=0,upper=n1> postpredk1;
  int<lower=0,upper=n2> postpredk2;
    
  // Posterior Predictive
  postpredk1 <- binomial_rng(n1, theta);
  postpredk2 <- binomial_rng(n2, theta);
}"""

sm=pystan.StanModel(model_code=two_exp_rate_gen)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_1070d695aa6003acbae0397bae8b9e8b NOW.
# /home/philip/anaconda3/envs/machine_learning/lib/python3.6/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpeou7br0y/stanfit4anon_model_1070d695aa6003acbae0397bae8b9e8b_2318406431593760825.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
fit1=sm.sampling(data=data_1,chains=4,iter=1000,seed=12329)


plt.hist(fit1['theta'])
plt.show()

fit2=sm.sampling(data=data_2,chains=4,iter=1000,seed=12329)


plt.hist(fit2['theta'])
plt.show()

# %%
fit1['postpredk1'][4]
# Out:
# 3.0

# %%
heatmap = np.zeros([11,11])

for x in np.arange(2000):
    heatmap[int(fit2['postpredk1'][x]), int(fit2['postpredk2'][x])] += 1

# %%
plt.imshow(heatmap, cmap='hot', interpolation='nearest')
plt.show()

# %% [markdown]
# <p> Not only is it useful to understand your model before you fit it, but to understand how well your data is explained by your model. Part of this process is creative but there are also tools that exist that can help. </p>
